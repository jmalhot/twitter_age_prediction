# %%
#https://github.com/kellypeng/predict_twitter_user_age/tree/master/src

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 1000000000)
pd.set_option('display.float_format', lambda x: '%.6f' % x)
pd.set_option('display.max_colwidth', 1000000)

# %%
'''
This is same as setting PYTHONPATH
'''
import sys
sys.path.append("/Users/jatin.malhotra/Desktop/ssense/git/better")

# %%
df_mentions = pd.read_csv('../data/mentions.csv')
df_friends = pd.read_csv('../data/friends.csv')
df_ages_train = pd.read_csv('../data/ages_train.csv')
df_ages_test = pd.read_csv('../data/ages_test.csv', header=None, names=['ID'])

# %%
df_ages_train.shape
# Out:
# (1711, 2)

# %%
df_ages_train.head(2)
# Out:
#           ID  Age
# 0   23605717   21
# 1  781084760   19

# %%
df_ages_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1711 entries, 0 to 1710
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      1711 non-null   int64
#  1   Age     1711 non-null   int64
# dtypes: int64(2)
# memory usage: 26.9 KB

# %%
df_ages_train['Age'].describe()
# Out:
# count   1711.000000
# mean      22.210403
# std        7.220109
# min       18.000000
# 25%       19.000000
# 50%       21.000000
# 75%       22.000000
# max      111.000000
# Name: Age, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from scipy import stats
from scipy.stats import norm, skew
    
def distribution_plot(df, col):

    figure = plt.figure(figsize=(18,10))
    plt.subplot(1,2,1)
    sns.distplot(df[col] , fit=norm);
    (mu, sigma) = norm.fit( df[col])
    plt.ylabel('Frequency')
    plt.title('Distribution')


    plt.subplot(1,2,2)
    stats.probplot(df[col], plot=plt)
    plt.show()

# %%
distribution_plot(df_ages_train, 'Age')

# %%
df_ages_train['Age'].value_counts(bins=10)
# Out:
# (17.906, 27.3]    1548
# (27.3, 36.6]       100
# (36.6, 45.9]        35
# (45.9, 55.2]        13
# (55.2, 64.5]         5
# (64.5, 73.8]         4
# (83.1, 92.4]         2
# (101.7, 111.0]       2
# (73.8, 83.1]         1
# (92.4, 101.7]        1
# Name: Age, dtype: int64

# %%
df_ages_train.ID.unique().shape
# Out:
# (1711,)

# %%
df_ages_test.head(2)
# Out:
#           ID
# 0  246677348
# 1   34014070

# %%
df_ages_test.shape
# Out:
# (300, 1)

# %%
def users_present_in_both_train_test(df_ages_train:pd.DataFrame, df_ages_test:pd.DataFrame):
    users_in_train_and_test_data=[]
    
    for user in df_ages_train.ID.unique():
        if user in df_ages_test.ID.unique().tolist():
            users_in_train_and_test_data.append(user)
    
    return users_in_train_and_test_data

# %%
print("Total Users in Test Dataset: ", len(df_ages_test))

print("Users present in both Train and Test Dataset: ", len(users_present_in_both_train_test(df_ages_train, df_ages_test)))
# Out:
# Total Uses in Test Dataset:  300
# Users present in both Train and Test Dataset:  300

# %% [markdown]
# <font size=4> Vaow! Test Data Set is just a sample of Train Dataset... Well, lets ignore this Nuance for the purpose
#     of this excercise

# %%
df_mentions.shape
# Out:
# (17695, 3)

# %%
df_mentions[df_mentions.ID==612815277]
# Out:
#           ID  MentionedID MentionedHandle
# 0  612815277    798747864    AlenaBacalia
# 1  612815277    354590068      hfholden34
# 2  612815277    401111769   MarilynYousif
# 3  612815277     35581752      heeeeyerin
# 4  612815277   1591956090      DogeTheDog
# 5  612815277     27356974         MrJeffJ
# 6  612815277    378734536   LindsayGorncy
# 7  612815277     30008146          tigers

# %%
df_mentions.ID.value_counts().to_frame().head(10)
# Out:
#             ID
# 315555817   51
# 2207254850  51
# 283449093   42
# 455777416   42
# 184928826   40
# 69856018    40
# 471401606   39
# 25953256    37
# 68877665    36
# 165163852   35

# %%
df_mentions.ID.value_counts().to_frame().tail(10)
# Out:
#             ID
# 844338115    1
# 818380764    1
# 72078217     1
# 862290169    1
# 34623318     1
# 87571990     1
# 2647789536   1
# 274875320    1
# 35362627     1
# 878793648    1

# %%
df_mentions_count = df_mentions.ID.value_counts().to_frame().reset_index()

# %%
df_mentions_count.columns=['ID', 'mentions_count']

# %%
df_mentions_count.head(3)
# Out:
#            ID  mentions_count
# 0   315555817              51
# 1  2207254850              51
# 2   283449093              42

# %%
len(df_mentions.MentionedID.unique())
# Out:
# 10744

# %%
df_friends.ID.unique().shape
# Out:
# (2342,)

# %%
df_friends.head(10)
# Out:
#           ID   FriendID
# 0  612815277  574147452
# 1  612815277   36767299
# 2  612815277   29374598
# 3  612815277   67634814
# 4  612815277   30008146
# 5  612815277   16826656
# 6  612815277   18219438
# 7  612815277   85920189
# 8  612815277  183654112
# 9  612815277  368540737

# %%
df_friends.ID.value_counts().to_frame().head(10)
# Out:
#             ID
# 612815277   20
# 1534955306  20
# 487646498   20
# 447535938   20
# 2195817611  20
# 2733135521  20
# 15175682    20
# 468060355   20
# 185402524   20
# 329669768   20

# %% [markdown]
# <font size = 4> <b> <p>Load User Objects (users, friends, mentiones) JSON data <p></b>
#  <font size = 4>   Loading data takes time so loading it once and caching it speeds up the process everytime I run the load

# %%
import json
import pandas as pd
import pickle
import os

def load_url_data(profile_url, profile_path, cache_file=True):
    
    cache_path =str(profile_path) + ".cache.pickle"
    
    if cache_file and os.path.exists(cache_path):
        print("Loading user_profile from cache: " + cache_path)
        with open(cache_path, 'rb') as f:
            cache = pickle.load(f)
            data = cache
    else:
        data = pd.read_json(profile_url)
        if cache_file:
            print("Dumping cache: " + cache_path)
            with open(cache_path, 'wb') as f:
                pickle.dump(data, f, pickle.HIGHEST_PROTOCOL)
                
    return data

# %%
user_profile_url = 'https://buapp-prod.s3.amazonaws.com/resources/hiring_ml_engineer_resources/age_profiles.json'
df_user_profile =load_url_data(user_profile_url, 'user_profile')


friends_profile_url = 'https://buapp-prod.s3.amazonaws.com/resources/hiring_ml_engineer_resources/friend_profiles.json'
df_friends_profile =load_url_data(friends_profile_url, 'friends_profile')


mention_profile_url = 'https://buapp-prod.s3.amazonaws.com/resources/hiring_ml_engineer_resources/mention_profiles.json'
df_mention_profile =load_url_data(mention_profile_url, 'mention_profile')


tweets_url = 'https://buapp-prod.s3.amazonaws.com/resources/hiring_ml_engineer_resources/age_tweets.json'
df_tweets =load_url_data(tweets_url, 'tweets')
# Out:
# Loading user_profile from cache: user_profile.cache.pickle
# Loading user_profile from cache: friends_profile.cache.pickle
# Loading user_profile from cache: mention_profile.cache.pickle
# Loading user_profile from cache: tweets.cache.pickle

# %% [markdown]
# <font size = 5> <b> TWEET OBJECT EDA

# %%
df_tweets.head(2)
# Out:
#    in_reply_to_status_id coordinates                                                                     text lang  in_reply_to_user_id_str                                              metadata                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     user place   geo                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# 0                    NaN        None  RT @AlenaBacalia: i over think and second guess everything way too much   en                      NaN  {'result_type': 'recent', 'iso_language_code': 'en'}  {'follow_request_sent': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/477666282871861249/Z62rKDZE_normal.jpeg', 'id_str': '612815277', 'name': 'Greggy', 'time_zone': 'Atlantic Time (Canada)', 'lang': 'en', 'profile_text_color': '333333', 'following': False, 'description': 'You'll never find another one like me.', 'protected': False, 'listed_count': 1, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'geo_enabled': True, 'profile_background_tile': True, 'profile_sidebar_fill_color': 'EFEFEF', 'location': '', 'favourites_count': 7937, 'profile_sidebar_border_color': 'EEEEEE', 'default_profile_image': False, 'profile_background_color': '131516', 'contributors_enabled': False, 'statuses_count': 12236, 'default_profile': False, 'entities': {'description': {'urls': []}}, 'profile_image_url': 'http://pbs.twimg.com/profile_images/477666282871861249/Z62rKDZE_normal.jpeg', 'verified': False, 'screen_name': 'agregtoremember', 'notifications': False, 'friends_count': 265, 'created_at': 'Tue Jun 19 17:54:58 +0000 2012', 'utc_offset': -10800, 'id': 612815277, 'is_translation_enabled': False, 'profile_link_color': '009999', 'url': None, 'is_translator': False, 'followers_count': 273, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/612815277/1400624131', 'profile_use_background_image': True}  None  None                 {'in_reply_to_status_id': None, 'coordinates': None, 'text': 'i over think and second guess everything way too much', 'lang': 'en', 'in_reply_to_user_id_str': None, 'metadata': {'result_type': 'recent', 'iso_language_code': 'en'}, 'user': {'follow_request_sent': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/513876108186767360/lyQSnW6n_normal.jpeg', 'id_str': '798747864', 'name': 'lena', 'time_zone': None, 'lang': 'en', 'profile_text_color': '333333', 'following': False, 'description': '19 | the mitten', 'protected': False, 'listed_count': 0, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'geo_enabled': False, 'profile_background_tile': False, 'profile_sidebar_fill_color': 'DDEEF6', 'location': '', 'favourites_count': 3470, 'profile_sidebar_border_color': 'C0DEED', 'default_profile_image': False, 'profile_background_color': 'C0DEED', 'contributors_enabled': False, 'statuses_count': 2703, 'default_profile': True, 'entities': {'url': {'urls': [{'display_url': 'itsaleeena.tumblr.com', 'expanded_url': 'http://itsaleeena.tumblr.com', 'url': 'http://t.co/KC0YZfgO4y', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'profile_image_url': 'http://pbs.twimg.com/profile_images/513876108186767360/lyQSnW6n_normal.jpeg', 'verified': False, 'screen_name': 'AlenaBacalia', 'notifications': False, 'friends_count': 227, 'created_at': 'Sun Sep 02 17:57:37 +0000 2012', 'utc_offset': None, 'id': 798747864, 'is_translation_enabled': False, 'profile_link_color': '0084B4', 'url': 'http://t.co/KC0YZfgO4y', 'is_translator': False, 'followers_count': 395, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/798747864/1409718835', 'profile_use_background_image': True}, 'place': None, 'geo': None, 'contributors': None, 'in_reply_to_screen_name': None, 'entities': {'hashtags': [], 'urls': [], 'symbols': [], 'user_mentions': []}, 'id_str': '515359279579410432', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id_str': None, 'retweet_count': 7, 'created_at': 'Fri Sep 26 04:36:41 +0000 2014', 'id': 515359279579410432, 'favorited': False, 'truncated': False, 'in_reply_to_user_id' ...
# 1                    NaN        None            RT @hfholden34: I've wasted too much time on the wrong people   en                      NaN  {'result_type': 'recent', 'iso_language_code': 'en'}  {'follow_request_sent': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/477666282871861249/Z62rKDZE_normal.jpeg', 'id_str': '612815277', 'name': 'Greggy', 'time_zone': 'Atlantic Time (Canada)', 'lang': 'en', 'profile_text_color': '333333', 'following': False, 'description': 'You'll never find another one like me.', 'protected': False, 'listed_count': 1, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'geo_enabled': True, 'profile_background_tile': True, 'profile_sidebar_fill_color': 'EFEFEF', 'location': '', 'favourites_count': 7937, 'profile_sidebar_border_color': 'EEEEEE', 'default_profile_image': False, 'profile_background_color': '131516', 'contributors_enabled': False, 'statuses_count': 12236, 'default_profile': False, 'entities': {'description': {'urls': []}}, 'profile_image_url': 'http://pbs.twimg.com/profile_images/477666282871861249/Z62rKDZE_normal.jpeg', 'verified': False, 'screen_name': 'agregtoremember', 'notifications': False, 'friends_count': 265, 'created_at': 'Tue Jun 19 17:54:58 +0000 2012', 'utc_offset': -10800, 'id': 612815277, 'is_translation_enabled': False, 'profile_link_color': '009999', 'url': None, 'is_translator': False, 'followers_count': 273, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/612815277/1400624131', 'profile_use_background_image': True}  None  None  {'in_reply_to_status_id': None, 'coordinates': None, 'text': 'I've wasted too much time on the wrong people', 'lang': 'en', 'in_reply_to_user_id_str': None, 'metadata': {'result_type': 'recent', 'iso_language_code': 'en'}, 'user': {'follow_request_sent': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/497607482580422656/H4GAMdhX_normal.jpeg', 'id_str': '354590068', 'name': 'Hannah Holden', 'time_zone': None, 'lang': 'en', 'profile_text_color': '333333', 'following': False, 'description': 'freshman in college', 'protected': False, 'listed_count': 13, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'geo_enabled': True, 'profile_background_tile': False, 'profile_sidebar_fill_color': 'DDEEF6', 'location': '256', 'favourites_count': 9975, 'profile_sidebar_border_color': 'C0DEED', 'default_profile_image': False, 'profile_background_color': 'C0DEED', 'contributors_enabled': False, 'statuses_count': 28512, 'default_profile': True, 'entities': {'url': {'urls': [{'display_url': 'Instagram.com/hholden34', 'expanded_url': 'http://Instagram.com/hholden34', 'url': 'http://t.co/YujDK6o0KN', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'profile_image_url': 'http://pbs.twimg.com/profile_images/497607482580422656/H4GAMdhX_normal.jpeg', 'verified': False, 'screen_name': 'hfholden34', 'notifications': False, 'friends_count': 3116, 'created_at': 'Sun Aug 14 00:05:16 +0000 2011', 'utc_offset': None, 'id': 354590068, 'is_translation_enabled': False, 'profile_link_color': '0084B4', 'url': 'http://t.co/YujDK6o0KN', 'is_translator': False, 'followers_count': 9012, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/354590068/1411516784', 'profile_use_background_image': True}, 'place': None, 'geo': None, 'contributors': None, 'in_reply_to_screen_name': None, 'entities': {'hashtags': [], 'urls': [], 'symbols': [], 'user_mentions': []}, 'id_str': '515349562761154560', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id_str': None, 'retweet_count': 80, 'created_at': 'Fri Sep 26 03:58:05 +0000 2014', 'id': 515349562761154560, 'favorited': False, 'truncated': False, 'in_reply_to_user_id': ...

# %%
df_tweets.shape
# Out:
# (28138, 25)

# %%
df_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28138 entries, 0 to 28137
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   in_reply_to_status_id      4839 non-null   float64
#  1   coordinates                1298 non-null   object
#  2   text                       28138 non-null  object
#  3   lang                       28138 non-null  object
#  4   in_reply_to_user_id_str    5299 non-null   float64
#  5   metadata                   28138 non-null  object
#  6   user                       28138 non-null  object
#  7   place                      1341 non-null   object
#  8   geo                        1298 non-null   object
#  9   retweeted_status           7645 non-null   object
#  10  contributors               0 non-null      float64
#  11  in_reply_to_screen_name    5299 non-null   object
#  12  entities                   28138 non-null  object
#  13  id_str                     28138 non-null  int64
#  14  favorited                  28138 non-null  bool
#  15  in_reply_to_status_id_str  4839 non-null   float64
#  16  retweet_count              28138 non-null  int64
#  17  created_at                 28138 non-null  datetime64[ns, UTC]
#  18  id                         28138 non-null  int64
#  19  source                     28138 non-null  object
#  20  truncated                  28138 non-null  bool
#  21  in_reply_to_user_id        5299 non-null   float64
#  22  favorite_count             28138 non-null  int64
#  23  retweeted                  28138 non-null  bool
#  24  possibly_sensitive         8168 non-null   float64
# dtypes: bool(3), datetime64[ns, UTC](1), float64(6), int64(4), object(11)
# memory usage: 4.8+ MB

# %%
df_tweets.describe()
# Out:
#           in_reply_to_status_id  in_reply_to_user_id_str  contributors                    id_str  in_reply_to_status_id_str  retweet_count                        id  in_reply_to_user_id  favorite_count  possibly_sensitive
# count               4839.000000              5299.000000      0.000000              28138.000000                4839.000000   28138.000000              28138.000000          5299.000000    28138.000000         8168.000000
# mean  515058332396179712.000000         658457680.662389           NaN 515326422855582464.000000  515058332396179712.000000     578.623214 515326422855582464.000000     658457680.662389        0.476438            0.020813
# std     7132846233866518.000000         765944186.505184           NaN    703425827700419.250000    7132846233866518.000000    5369.071823    703425827700419.250000     765944186.505184        7.386489            0.142766
# min   105372771084812288.000000             46023.000000           NaN 512992536554926080.000000  105372771084812288.000000       0.000000 512992536554926080.000000         46023.000000        0.000000            0.000000
# 25%   514941493048784896.000000         152126446.000000           NaN 514988235770009600.000000  514941493048784896.000000       0.000000 514988235770009600.000000     152126446.000000        0.000000            0.000000
# 50%   515554208821829632.000000         350069503.000000           NaN 515574163751579648.000000  515554208821829632.000000       0.000000 515574163751579648.000000     350069503.000000        0.000000            0.000000
# 75%   515885526973503488.000000         791049271.000000           NaN 515882540799121408.000000  515885526973503488.000000       1.000000 515882540799121408.000000     791049271.000000        0.000000            0.000000
# max   516081213639897088.000000        2832293652.000000           NaN 516082911603621888.000000  516081213639897088.000000  232629.000000 516082911603621888.000000    2832293652.000000      681.000000            1.000000

# %%
df_tweets.isna().sum().sort_values(ascending=False)
# Out:
# contributors                 28138
# coordinates                  26840
# geo                          26840
# place                        26797
# in_reply_to_status_id        23299
# in_reply_to_status_id_str    23299
# in_reply_to_user_id          22839
# in_reply_to_user_id_str      22839
# in_reply_to_screen_name      22839
# retweeted_status             20493
# possibly_sensitive           19970
# user                             0
# metadata                         0
# id_str                           0
# favorited                        0
# lang                             0
# retweet_count                    0
# created_at                       0
# id                               0
# source                           0
# truncated                        0
# text                             0
# favorite_count                   0
# retweeted                        0
# entities                         0
# dtype: int64

# %%
'''
Parse USER_ID from user column: user column is a replica of user profile object. 
'''

df_tweets['user_id'] = pd.json_normalize(df_tweets.user)['id']

# %%
df_tweets.head(1)
# Out:
#    in_reply_to_status_id coordinates                                                                     text lang  in_reply_to_user_id_str                                              metadata                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     user place   geo                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# 0                    NaN        None  RT @AlenaBacalia: i over think and second guess everything way too much   en                      NaN  {'result_type': 'recent', 'iso_language_code': 'en'}  {'follow_request_sent': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/477666282871861249/Z62rKDZE_normal.jpeg', 'id_str': '612815277', 'name': 'Greggy', 'time_zone': 'Atlantic Time (Canada)', 'lang': 'en', 'profile_text_color': '333333', 'following': False, 'description': 'You'll never find another one like me.', 'protected': False, 'listed_count': 1, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'geo_enabled': True, 'profile_background_tile': True, 'profile_sidebar_fill_color': 'EFEFEF', 'location': '', 'favourites_count': 7937, 'profile_sidebar_border_color': 'EEEEEE', 'default_profile_image': False, 'profile_background_color': '131516', 'contributors_enabled': False, 'statuses_count': 12236, 'default_profile': False, 'entities': {'description': {'urls': []}}, 'profile_image_url': 'http://pbs.twimg.com/profile_images/477666282871861249/Z62rKDZE_normal.jpeg', 'verified': False, 'screen_name': 'agregtoremember', 'notifications': False, 'friends_count': 265, 'created_at': 'Tue Jun 19 17:54:58 +0000 2012', 'utc_offset': -10800, 'id': 612815277, 'is_translation_enabled': False, 'profile_link_color': '009999', 'url': None, 'is_translator': False, 'followers_count': 273, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/612815277/1400624131', 'profile_use_background_image': True}  None  None  {'in_reply_to_status_id': None, 'coordinates': None, 'text': 'i over think and second guess everything way too much', 'lang': 'en', 'in_reply_to_user_id_str': None, 'metadata': {'result_type': 'recent', 'iso_language_code': 'en'}, 'user': {'follow_request_sent': False, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/513876108186767360/lyQSnW6n_normal.jpeg', 'id_str': '798747864', 'name': 'lena', 'time_zone': None, 'lang': 'en', 'profile_text_color': '333333', 'following': False, 'description': '19 | the mitten', 'protected': False, 'listed_count': 0, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'geo_enabled': False, 'profile_background_tile': False, 'profile_sidebar_fill_color': 'DDEEF6', 'location': '', 'favourites_count': 3470, 'profile_sidebar_border_color': 'C0DEED', 'default_profile_image': False, 'profile_background_color': 'C0DEED', 'contributors_enabled': False, 'statuses_count': 2703, 'default_profile': True, 'entities': {'url': {'urls': [{'display_url': 'itsaleeena.tumblr.com', 'expanded_url': 'http://itsaleeena.tumblr.com', 'url': 'http://t.co/KC0YZfgO4y', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'profile_image_url': 'http://pbs.twimg.com/profile_images/513876108186767360/lyQSnW6n_normal.jpeg', 'verified': False, 'screen_name': 'AlenaBacalia', 'notifications': False, 'friends_count': 227, 'created_at': 'Sun Sep 02 17:57:37 +0000 2012', 'utc_offset': None, 'id': 798747864, 'is_translation_enabled': False, 'profile_link_color': '0084B4', 'url': 'http://t.co/KC0YZfgO4y', 'is_translator': False, 'followers_count': 395, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/798747864/1409718835', 'profile_use_background_image': True}, 'place': None, 'geo': None, 'contributors': None, 'in_reply_to_screen_name': None, 'entities': {'hashtags': [], 'urls': [], 'symbols': [], 'user_mentions': []}, 'id_str': '515359279579410432', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id_str': None, 'retweet_count': 7, 'created_at': 'Fri Sep 26 04:36:41 +0000 2014', 'id': 515359279579410432, 'favorited': False, 'truncated': False, 'in_reply_to_user_id': None, 'favori ...

# %%
df_tweets['metadata'].value_counts().to_frame().head(10)
# Out:
#                                                        metadata
# {'result_type': 'recent', 'iso_language_code': 'en'}      24605
# {'result_type': 'recent', 'iso_language_code': 'und'}      1424
# {'result_type': 'recent', 'iso_language_code': 'tl'}        515
# {'result_type': 'recent', 'iso_language_code': 'in'}        461
# {'result_type': 'recent', 'iso_language_code': 'es'}        269
# {'result_type': 'recent', 'iso_language_code': 'ar'}        131
# {'result_type': 'recent', 'iso_language_code': 'ht'}         93
# {'result_type': 'recent', 'iso_language_code': 'pt'}         93
# {'result_type': 'recent', 'iso_language_code': 'th'}         89
# {'result_type': 'recent', 'iso_language_code': 'nl'}         72

# %%
df_tweets['coordinates'].value_counts().to_frame().head(10)
# Out:
#                                                               coordinates
# {'type': 'Point', 'coordinates': [120.8032344, 14.8576781]}            11
# {'type': 'Point', 'coordinates': [-90.5562803, 41.4941617]}            10
# {'type': 'Point', 'coordinates': [-82.74019541, 27.8018018]}            6
# {'type': 'Point', 'coordinates': [-84.329154, 33.8282342]}              6
# {'type': 'Point', 'coordinates': [-97.8433951, 30.5229312]}             6
# {'type': 'Point', 'coordinates': [-2.5769663, 53.3933165]}              6
# {'type': 'Point', 'coordinates': [-82.78985037, 28.0]}                  5
# {'type': 'Point', 'coordinates': [121.0836641, 14.3291226]}             5
# {'type': 'Point', 'coordinates': [-2.1774562, 53.0109764]}              4
# {'type': 'Point', 'coordinates': [27.812361, -26.2263344]}              4

# %%
df_tweets['possibly_sensitive'].value_counts()
# Out:
# 0.000000    7998
# 1.000000     170
# Name: possibly_sensitive, dtype: int64

# %%
'''
favorited: feature does not make sense as it has just one value - False
'''
df_tweets['favorited'].value_counts()
# Out:
# False    28138
# Name: favorited, dtype: int64

# %%
'''
retweeted: feature does not make sense as it has just one value - False
'''
df_tweets['retweeted'].value_counts()
# Out:
# False    28138
# Name: retweeted, dtype: int64

# %%
'''
truncated: feature does not make sense as it has just one value - False
'''
df_tweets['truncated'].value_counts()
# Out:
# False    28138
# Name: truncated, dtype: int64

# %%
TWEET_FEATURES = ['text', 'lang', 'user_id', 'retweet_count', 'created_at', 'id', 'source',
                 'favorite_count', 'possibly_sensitive', 'entities']

# %%
df_tweets = df_tweets[TWEET_FEATURES]

# %%
'''
Parse Tweet Source as it may have meaningfull information
'''
from bs4 import BeautifulSoup
df_tweets['source_parsed'] = df_tweets['source'].apply(lambda x: BeautifulSoup(str(x),'html.parser').text)

# %%
df_tweets.head(2)
# Out:
#                                                                       text lang    user_id  retweet_count                created_at                  id                                                                              source  favorite_count  possibly_sensitive                                                                                                                                                                            entities       source_parsed
# 0  RT @AlenaBacalia: i over think and second guess everything way too much   en  612815277              7 2014-09-26 05:55:45+00:00  515379174454747136  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>               0                 NaN         {'hashtags': [], 'urls': [], 'symbols': [], 'user_mentions': [{'id': 798747864, 'indices': [3, 16], 'screen_name': 'AlenaBacalia', 'id_str': '798747864', 'name': 'lena'}]}  Twitter for iPhone
# 1            RT @hfholden34: I've wasted too much time on the wrong people   en  612815277             80 2014-09-26 05:58:17+00:00  515379813670854656  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>               0                 NaN  {'hashtags': [], 'urls': [], 'symbols': [], 'user_mentions': [{'id': 354590068, 'indices': [3, 14], 'screen_name': 'hfholden34', 'id_str': '354590068', 'name': 'Hannah Holden'}]}  Twitter for iPhone

# %%
df_tweets['source_parsed'].value_counts(normalize=True)*100
# Out:
# Twitter for iPhone            54.872415
# Twitter for Android           18.100078
# Instagram                      5.341531
# Twitter Web Client             5.025233
# IFTTT                          1.709432
# Echofon                        1.499751
# Twitter for iPad               1.226100
# Twittascope                    1.187007
# Twitter for Windows Phone      1.055512
# Mobile Web (M5)                0.863601
# Facebook                       0.749876
# Twitter for BlackBerry®        0.742768
# TweetCaster for Android        0.636150
# Plume for Android              0.625489
# Twitter for Android Tablets    0.493994
# Tweetbot for iΟS               0.462009
# Tweetlogix                     0.412254
# iOS                            0.394484
# Unfollowers.me                 0.376715
# TweetDeck                      0.341176
# Mobile Web (M2)                0.341176
# Twitter for Websites           0.291421
# Cloudhopper                    0.209681
# fllwrs                         0.202573
# Tumblr                         0.199019
# dlvr.it                        0.195465
# Twitter for BlackBerry         0.188357
# Path                           0.184803
# Twitter for  Android           0.163480
# Twitter for Mac                0.149264
# Foursquare                     0.149264
# TweetCaster for iOS            0.138603
# Timehop                        0.131495
# Vine - Make a Scene            0.099510
# Hootsuite                      0.088848
# Seesmic                        0.071078
# Watchgram                      0.071078
# Echofon  Android               0.071078
# Google                         0.067524
# UberSocial for BlackBerry      0.063970
# twicca                         0.063970
# Dynamic Tweets                 0.053309
# Yelp                           0.053309
# Osfoora for iOS                0.053309
# JustUnfollow                   0.049755
# Depop                          0.046201
# UberSocial for Android         0.046201
# Ask.fm                         0.046201
# Vine for Android               0.035539
# ValueMyTweets                  0.028431
# Fenix for Android              0.028431
# Tweetbot for Mac               0.024877
# IHeartNicoleUS                 0.021323
# Ayat | آيات                    0.017770
# Twitter for Windows            0.014216
# Buffer                         0.014216
# Goodreads                      0.010662
# Coast 2 Coast Mixtapes         0.010662
# UberSocial for iPhone          0.010662
# PlayStation(R)4                0.010662
# Bloglovin                      0.010662
# PromoSimple                    0.010662
# ReverbNation                   0.010662
# Bible                          0.007108
# Linkis.com                     0.007108
# Twitter MMS                    0.007108
# SoundCloud                     0.007108
# WordPress.com                  0.007108
# Shots App                      0.007108
# X Factor 2014                  0.007108
# Untappd                        0.007108
# LG Phone                       0.007108
# Spotify                        0.003554
# Twitter for MediaTek Phones    0.003554
# Twitter for Nokia S40          0.003554
# AdultWork.com                  0.003554
# Twitcom - Comunidades          0.003554
# Spreaker                       0.003554
# trakt                          0.003554
# Pandora                        0.003554
# Kim Kardashian: Hollywood      0.003554
# TweetAdder v4                  0.003554
# Nike Test App                  0.003554
# Twitlonger                     0.003554
# 8 Ball Pool™ on iOS            0.003554
# Sony Xperia™ smartphone        0.003554
# Photos on iOS                  0.003554
# unfalert.com                   0.003554
# OS X                           0.003554
# PledgeMusic                    0.003554
# dailymile                      0.003554
# Instagram on iOS               0.003554
# Name: source_parsed, dtype: float64

# %%
from datetime import datetime
def get_day_of_week(date):
    """
    input: date
    purpose: extracts day of the week from date
    output: day of the week
    """
    l_day_of_week = date.strftime('%A')

    
    return l_day_of_week #week_mapper(l_day_of_week)

# %%
df_tweets['creation_day_of_week'] = df_tweets['created_at'].apply(lambda x: get_day_of_week(x))

# %%
df_tweets.drop(columns = ['created_at', 'source'], inplace=True)

# %%
df_tweets.head(2)
# Out:
#                                                                       text lang    user_id  retweet_count                  id  favorite_count  possibly_sensitive                                                                                                                                                                            entities       source_parsed creation_day_of_week
# 0  RT @AlenaBacalia: i over think and second guess everything way too much   en  612815277              7  515379174454747136               0                 NaN         {'hashtags': [], 'urls': [], 'symbols': [], 'user_mentions': [{'id': 798747864, 'indices': [3, 16], 'screen_name': 'AlenaBacalia', 'id_str': '798747864', 'name': 'lena'}]}  Twitter for iPhone               Friday
# 1            RT @hfholden34: I've wasted too much time on the wrong people   en  612815277             80  515379813670854656               0                 NaN  {'hashtags': [], 'urls': [], 'symbols': [], 'user_mentions': [{'id': 354590068, 'indices': [3, 14], 'screen_name': 'hfholden34', 'id_str': '354590068', 'name': 'Hannah Holden'}]}  Twitter for iPhone               Friday

# %%
df_tweets['lang'].value_counts()
# Out:
# en     24605
# und     1424
# tl       515
# in       461
# es       269
# ar       131
# ht        93
# pt        93
# th        89
# nl        72
# ja        49
# fr        43
# it        42
# et        40
# sk        32
# pl        29
# de        25
# sv        24
# ko        19
# da        14
# fi        13
# tr        10
# lv         7
# vi         7
# no         6
# lt         6
# zh         5
# sl         5
# hu         4
# iw         2
# ru         1
# hi         1
# el         1
# bg         1
# Name: lang, dtype: int64

# %%
df_tweets['user_id'].value_counts().to_frame().head(10)
# Out:
#             user_id
# 2366660952       20
# 208174517        20
# 321547376        20
# 310058378        20
# 166799040        20
# 217009280        20
# 52910892         20
# 735086305        20
# 333132730        20
# 138947254        20

# %%
df_tweets.head(5)
# Out:
#                                                                                     text lang    user_id  retweet_count                  id  favorite_count  possibly_sensitive                                                                                                                                                                            entities        source_parsed creation_day_of_week
# 0                RT @AlenaBacalia: i over think and second guess everything way too much   en  612815277              7  515379174454747136               0                 NaN         {'hashtags': [], 'urls': [], 'symbols': [], 'user_mentions': [{'id': 798747864, 'indices': [3, 16], 'screen_name': 'AlenaBacalia', 'id_str': '798747864', 'name': 'lena'}]}   Twitter for iPhone               Friday
# 1                          RT @hfholden34: I've wasted too much time on the wrong people   en  612815277             80  515379813670854656               0                 NaN  {'hashtags': [], 'urls': [], 'symbols': [], 'user_mentions': [{'id': 354590068, 'indices': [3, 14], 'screen_name': 'hfholden34', 'id_str': '354590068', 'name': 'Hannah Holden'}]}   Twitter for iPhone               Friday
# 2                                                                      I'm already gone.   en  612815277              1  515380190361288704               1                 NaN                                                                                                                    {'hashtags': [], 'urls': [], 'symbols': [], 'user_mentions': []}   Twitter for iPhone               Friday
# 3                  I'm already something to someone that I don't know. When will I know?   en  612815277              0  515380273005854721               1                 NaN                                                                                                                    {'hashtags': [], 'urls': [], 'symbols': [], 'user_mentions': []}   Twitter for iPhone               Friday
# 4  I don't know what I'm doing with my life, but all I know if that I'm doing it for me.   en  612815277              0  515412946608852992               1                 NaN                                                                                                                    {'hashtags': [], 'urls': [], 'symbols': [], 'user_mentions': []}  Twitter for Android               Friday

# %%
df_mention_profile[df_mention_profile.id==354590068]
# Out:
#    screen_name  follow_request_sent  following                                          profile_banner_url profile_text_color     id_str  notifications         id  friends_count                                                                                                                                                                                             entities                                                            profile_image_url  default_profile_image  listed_count           name                      profile_background_image_url profile_sidebar_border_color  verified lang profile_link_color          description profile_background_color profile_sidebar_fill_color  default_profile  utc_offset  is_translator  profile_use_background_image                                                       profile_image_url_https  statuses_count location                 profile_background_image_url_https  favourites_count  followers_count  profile_background_tile  is_translation_enabled                created_at  protected  geo_enabled time_zone  contributors_enabled                     url                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         status
# 70  hfholden34                False      False  https://pbs.twimg.com/profile_banners/354590068/1411516784             333333  354590068          False  354590068           3155  {'description': {'urls': []}, 'url': {'urls': [{'indices': [0, 22], 'expanded_url': 'http://Instagram.com/hholden34', 'display_url': 'Instagram.com/hholden34', 'url': 'http://t.co/YujDK6o0KN'}]}}  http://pbs.twimg.com/profile_images/497607482580422656/H4GAMdhX_normal.jpeg                  False            13  Hannah Holden  http://abs.twimg.com/images/themes/theme1/bg.png                       C0DEED     False   en             0084B4  freshman in college                   C0DEED                     DDEEF6             True         NaN          False                          True  https://pbs.twimg.com/profile_images/497607482580422656/H4GAMdhX_normal.jpeg           28546      256  https://abs.twimg.com/images/themes/theme1/bg.png              9996             9146                    False                   False 2011-08-14 00:05:16+00:00      False         True      None                 False  http://t.co/YujDK6o0KN  {'truncated': False, 'retweeted': False, 'contributors': None, 'geo': None, 'place': None, 'entities': {'urls': [], 'symbols': [], 'hashtags': [], 'user_mentions': []}, 'coordinates': None, 'favorited': False, 'created_at': 'Mon Sep 29 04:33:34 +0000 2014', 'in_reply_to_screen_name': None, 'lang': 'en', 'id': 516445657955971074, 'in_reply_to_status_id': None, 'favorite_count': 41, 'in_reply_to_user_id': None, 'text': 'I was just another promise you couldn't keep', 'id_str': '516445657955971074', 'retweet_count': 22, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id_str': None, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>'}

# %%
'''
Take first user mentioned in the tweet. Null if no user is mentioned
'''
#df_tweets['first_mention_id'] = pd.json_normalize(pd.json_normalize(pd.json_normalize(df_tweets.entities)['user_mentions'])[0])['id']
# Out:
# '\nTake first user mentioned in the tweet. Null if no user is mentioned\n'

# %%
df_tweets.drop(columns= ['entities'], inplace=True)

# %%
df_tweets[df_tweets.lang !='en'].head(30)
# Out:
#                                                                                                                                                        text lang     user_id  retweet_count                  id  favorite_count  possibly_sensitive              source_parsed creation_day_of_week
# 32                                                                                                                                                      ♌💯✔  und   264416315              0  515331571771928577               0                 NaN        Twitter for Android               Friday
# 53                                                                                                            #loveit #scrapbookpics http://t.co/0w8huvX6pJ  und    97515432              0  515779250654568448               0            0.000000          Plume for Android             Saturday
# 57                                                                                                                             &lt;3 http://t.co/FqJ4yCa5N4  und    97515432              0  515780729733914624               0            0.000000          Plume for Android             Saturday
# 71                                                                                                                                    @BEACHBOY_MILES hmmmm  und   271608323              0  515668230414012416               0                 NaN        Twitter for Android             Saturday
# 74                                                                                                                               @BEACHBOY_MILES okey dokey   sv   271608323              0  515671824982900736               0                 NaN        Twitter for Android             Saturday
# 77                                                                                                                                              @semaj_oo 3  und   271608323              0  515868334299308032               0                 NaN        Twitter for Android             Saturday
# 80                                                                                            RT @Topaz_Kid: "@iAmReallyChris: Me 😩 http://t.co/VepcDtnUML"  und   224078321              6  515698356254150656               0            0.000000        Twitter for Android             Saturday
# 87                                                                                                               Freeeeeee @MeekMill http://t.co/mtozDuHEso  und   224078321              2  515868251709276161               0            0.000000        Twitter for Android             Saturday
# 95                                                                                                                                             @B3rries_ 😩😩  und   314345007              0  513697782847533056               0                 NaN         Twitter for iPhone               Sunday
# 97                                                                                                                        @B3rries_ @xBeautyMarkedx wahhhh😩  und   314345007              0  513698891145805824               0                 NaN         Twitter for iPhone               Sunday
# 99                                                                                                                                    Jalapeño chips r bomb   es   314345007              2  513744197737013248               2                 NaN         Twitter for iPhone               Sunday
# 100                                                                                                       @B3rries_ @xBeautyMarkedx @TypicalMinions 😩😂😂😂😂😂😂  und   314345007              0  513796610657366017               0                 NaN         Twitter for iPhone               Sunday
# 101                                                                                                                               ❤️ http://t.co/RACUdsIG8x  und   314345007              0  514454187250565120               3            0.000000         Twitter for iPhone              Tuesday
# 128                                                                                                                         !!!!!!!! http://t.co/VKKDJUEFSf  und   249775709              0  515671287965167616               0            0.000000                  Instagram             Saturday
# 141                                                                                                                                            @aaalivi alr  und   247434515              0  514817586497077249               0                 NaN         Twitter for iPhone            Wednesday
# 168                                                                                     Cliché couple picture 🍍 @ Pineapple Fountain http://t.co/jFmIxER4Si   fr   446663800              0  515614832892985347               0            0.000000                  Instagram               Friday
# 188                                                                                                                                       @daddyajay_ Mhm 👌  und   269839050              0  515696768185806849               0                 NaN         Twitter for iPhone             Saturday
# 218                                                                                                RT @Nessabm11: “@Brandan420_: 💯 http://t.co/FWVEnp7q2F”😂  und  2246180454              1  515939370109763584               0            0.000000         Twitter for iPhone             Saturday
# 268                                                                                                                       #yesterday http://t.co/1XZSVAvZU1  und   200977178              0  515517912493592576               2            0.000000         Twitter for iPhone               Friday
# 271                                                                                                                                  http://t.co/R9nwkoNriu  und    40604337              0  513478157870333953               0            0.000000        Twitter for Android               Sunday
# 295                                                                                                                                         @BelleDamex3 ❤️  und    31637278              0  515783964930629632               0                 NaN         Twitter for iPhone             Saturday
# 310                                                                                                               @DJUNDERGROUNDNY @ThankYouSAB_FW blanco 😒   es    31637278              0  515592274164846592               0                 NaN         Twitter for iPhone               Friday
# 313                                                                                                                                           @Shmurda_Yo 👀  und    31637278              0  515653213383827456               0                 NaN         Twitter for iPhone             Saturday
# 316                                                                                                                                    #InKirkWeTrust #HTTR  und   193563712              0  515291359817658369               0                 NaN         Twitter for iPhone               Friday
# 327                                                                                                                              #Forever21 #HTTR @Redskins  und   193563712              0  515672523145359361               0                 NaN         Twitter for iPhone             Saturday
# 351                                                                                                            RT @_GEMINI_PRINCE: 👌 http://t.co/lvl7hUfdLa  und   319016379             13  515721655801626624               0            0.000000        Twitter for Android             Saturday
# 362                                                                                                                                               4:51 😴💤✌️  und    22107297              0  515785745211351040               0                 NaN         Twitter for iPhone             Saturday
# 363                                                                                                                                                 GM 😊👋👋😘  und    22107297              0  515887152132276225               0                 NaN         Twitter for iPhone             Saturday
# 377                                                                                         Churros and margaritas 😋 @ rosa mexicana http://t.co/gMdQs56Pcx   es   161918484              0  514210381787856896               0            0.000000                  Instagram              Tuesday
# 405   RT @tigers: #Tigers lineup vs. CWS:\nKinsler 2B\nHunter RF\nCabrera 1B\nV. Martinez DH\nJ. Martinez LF\nCastellanos 3B\nAvila C\nRomine SS\nCarrera …   vi   167884846            124  514176975230214144               0                 NaN         Twitter for iPhone               Monday
# 414                                                                                                          RT @FactsAboutBoys: tbh http://t.co/Sc9ttSMeWV  und   369326528           1609  513390540126449664               0            0.000000         Twitter for iPhone             Saturday
# 426                                           RT @bigpimpin319: "@ComedyTextings: Savage http://t.co/fAlN3CcjYw"@MakeItRainwater @GregoryBonomo @seanbaum22   fr   369326528              1  515559283581534208               0            0.000000         Twitter for iPhone               Friday
# 467                                                                                                                                            @BuzzFeed me  und  2718214807              0  513146161386233858               0                 NaN         Twitter for iPhone             Saturday
# 474                                                                                                                                            Julia Baker.   no    48621354              0  515305796570460160               0                 NaN     Twitter for BlackBerry               Friday
# 477                                                                                                                                                    Wth?  und    48621354              0  515310768255152128               0                 NaN     Twitter for BlackBerry               Friday
# 540                                                                                                                         RT @LFC: GOAL! JORDAN ROSSITER!   nl  2325271081           2794  514488211419435009               0                 NaN  Twitter for Windows Phone              Tuesday
# 548                                                                                                              RT @HistoricalPics: http://t.co/VJl3tl3OB8  und  2325271081           1406  515652334274482176               0            0.000000  Twitter for Windows Phone             Saturday
# 558                                                                                                                                            #MyLifeStyle  und   362888589              0  515647769282093056               0                 NaN         Twitter for iPhone               Friday
# 561                                                                                                                                        Oooo #theyMadToo  und   362888589              0  515725723194392576               0                 NaN         Twitter for iPhone             Saturday
# 567                                                                                                          Siopaaaoooo! Bakit walang siopao na emoji? 😂😂😂   tl   232099397              0  515807477007273984               0                 NaN         Twitter for iPhone             Saturday
# 572                                                                                                Wala na facebook, bulok na. Di na ako makalog in hahaha!   tl   232099397              0  515820686468579329               1                 NaN         Twitter for iPhone             Saturday
# 573                                                                                                                             #LSS http://t.co/qZWKo8M4NH  und   232099397              0  515880069462384641               0            0.000000         Twitter for iPhone             Saturday
# 578                                                                                                                  @piggeeMErry Nestea lang naman eh haha   tl   232099397              0  515893937806917632               0                 NaN         Twitter for iPhone             Saturday
# 579                                                                                                          Mommy ko yan eh haha ❤️ http://t.co/6VnrvtAKdu   tl   232099397              0  515900861411651584               1            0.000000         Twitter for iPhone             Saturday
# 600                                                                                            “@reIatabIe: #RelationshipGoals 🌹💕 http://t.co/l372e3bvmH”🙊😢  und   376336364              0  514082315656765441               0            0.000000         Twitter for iPhone               Monday
# 662                                                                                                                                      @ibreakrules__ sos  und   283245426              0  515155232230506496               0                 NaN        Twitter for Android             Thursday
# 694         RT @jeune_afrique: #BurkinaFaso : 4 octobre 1984, le discours historique de #Sankara à l'#ONU &gt; http://t.co/L8oHn4wCBV http://t.co/k9kShjKc…   fr   134965175            124  515502849967783936               0            0.000000         Twitter for iPhone               Friday
# 698                                                                                                  May kausap akong baboy kagabi 😂 http://t.co/N9BztPq9pR   tl   321954250              0  515309470277070848               0            0.000000         Twitter for iPhone               Friday
# 699                                                                                                                                                   Enebe   es   321954250              0  515309713567670272               0                 NaN         Twitter for iPhone               Friday
# 700                                                                                                                                         Eh nilalagnat 😑   tl   321954250              0  515440723206737920               1                 NaN         Twitter for iPhone               Friday
# 702                                                                                                                             Hndi pa pala ako kumakain 😑   tl   321954250              0  515447116181667840               0                 NaN         Twitter for iPhone               Friday
# 706                                                                                                                 38.9 😷😣\n#Sick 💔 http://t.co/RlrurjLFcy  und   321954250              0  515453809397878784               0            0.000000                  Instagram               Friday
# 707                                                                                                                            HAHAHAHA PUTANGINA ANG SAKIT   tl   321954250              0  515523158569254913               0                 NaN         Twitter for iPhone               Friday
# 709                                                                                                                            YESSS http://t.co/ZUutT5GPi6  und   321954250              0  515562205001965569               0            0.000000         Twitter for iPhone               Friday
# 711                                                                                                                    Eh maria talaga tawag niya saken 😂❤️   tl   321954250              0  515577956303785984               0                 NaN         Twitter for iPhone               Friday
# 714                                      “@ShitHappensDre: Ang luha, parang pawis. Di man parehong galing sa mata, pero parehong tumutulo pag pagod ka na.”   tl   321954250              0  515120824798281730               0                 NaN         Twitter for iPhone             Thursday
# 716                                   RT @MisterBanatero: Ang babae. Moody, selosa, hindi makapag desisyon ng maayos. Pero kahit ganyan yan, mahal ka nyan.   tl   321954250            478  515120880154705920               0                 NaN         Twitter for iPhone             Thursday
# 750             @Kayleig94852038 ❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️   sk   220415263              0  514749022259916800               1                 NaN         Twitter for iPhone            Wednesday
# 756                                                                                       "@freekuntye: Jlo mama... TRY AGAIN HOE http://t.co/rl9XYZRBZA" 💀   in   313041646              0  514209812775960577               0            0.000000        Twitter for Android              Tuesday
# 773                                                                                                                          @xo_elainemarie no problem! ☺️   pt  1944818563              0  515894190128242688               0                 NaN         Twitter for iPhone             Saturday
# 806                                                                                                                                      在你离开之后的天空 我像风筝寻一个梦   zh    59754795              0  515416351117045760               0                 NaN         Twitter Web Client               Friday
# 826                                                                                                                                          @kteberhart 😂😂  und   375400689              0  515175162782957568               2                 NaN         Twitter for iPhone             Thursday
# 827                                                                                                                                      @EverettIngalls4 🙋  und   375400689              0  515177570552528897               1                 NaN         Twitter for iPhone             Thursday
# 859                                                                                                                                             @jmo760 wtf  und   236098187              0  515236916967780352               0                 NaN         Twitter for iPhone             Thursday
# 873                                                                                                                                    NYC @SummerCosmetics  und   236098187              1  515941692470751232               3                 NaN         Twitter for iPhone             Saturday
# 877                                                                                                       @louise_irene @ItsFoodPorn @alexis_corpus1 yes!!!  und   489100566              0  514547578051244032               0                 NaN         Twitter for iPhone              Tuesday
# 888                                                                                                                                  http://t.co/Sv5w4oUeIx  und   489100566              0  515409722607149056               0            0.000000         Twitter for iPhone               Friday
# 899                                                                                                                                      @rob7890 ewww haha   tl   225090983              0  515240784153825280               0                 NaN         Twitter for iPhone             Thursday
# 900                                                                                                                                              @rob7890 🙈  und   225090983              0  515242202327678978               0                 NaN         Twitter for iPhone             Thursday
# 959                                                                                                                          @JamesRenwick_ 😂😂😂😂 #deeptweet  und   270414588              0  513410464668459008               0                 NaN         Twitter for iPhone             Saturday
# 965                                                                                                                                             ❤️ PEACE ❤️   et   270414588              0  513755352991825922               2                 NaN         Twitter for iPhone               Sunday
# 966                                                                                                                                 @CallumRobbo__ ☝️☝️☝️☝️   sk   270414588              0  513782659890548736               1                 NaN         Twitter for iPhone               Sunday
# 971                                                                                       RT @MusicForCanada: http://t.co/RbmFnJwyJg http://t.co/B7BXRgBLmM  und   393621283              1  514460837025968128               0            0.000000         Twitter for iPhone              Tuesday
# 982                                                                 RT @_fee_xo: @AsapAngie_ @Okinaaa_xox @simbaaa_xo @_Nanaax33 ‼️😝 http://t.co/BAm3RICm6I  und   552689765              3  515920446093791233               0            0.000000         Twitter for iPhone             Saturday
# 998                                                                                                                                            Nail salon 💅   tl   435100443              0  515589615454273537               0                 NaN         Twitter for iPhone               Friday
# 999                                                                                                                                            @TsukiPush a  und  2670277734              0  515896043477544961               0                 NaN         Twitter Web Client             Saturday
# 1000                                                                                                                                           @TsukiPush l  und  2670277734              0  515896049848709120               0                 NaN         Twitter Web Client             Saturday
# 1001                                                                                                                                           @TsukiPush m  und  2670277734              0  515896063467593728               0                 NaN         Twitter Web Client             Saturday
# 1010                                                                                                                               the bari sax wowowowoowo   in  2670277734              0  515897546820956160               0                 NaN         Twitter Web Client             Saturday
# 1011                                                                                                                                          hnnnngggggggg  und  2670277734              0  515897690022875136               0                 NaN         Twitter Web Client             Saturday
# 1012                                                                                                                                                orgasms   in  2670277734              0  515897744464965632               1                 NaN         Twitter Web Client             Saturday
# 1014                                                                                                                                                   y33t  und  2670277734              0  515893760866021376               0                 NaN         Twitter Web Client             Saturday
# 1016                                                                                                                                             h3y n1gg45   fr  2670277734              0  515893893645090817               1                 NaN         Twitter Web Client             Saturday
# 1017                                                                                                                                          4m 1 c001 y37   es  2670277734              0  515893952134643712               1                 NaN         Twitter Web Client             Saturday
# 1018                                                                                                                                                    3m1  und  2670277734              0  515893985395474432               0                 NaN         Twitter Web Client             Saturday
# 1032                                                                                                              @Sweekuh strong password= Sw3EkUh1zAv1c11  und   887591574              0  515921529595785216               1                 NaN        Twitter for Android             Saturday
# 1058                                                                                         Paul C &amp; Paolo Martini - Waterdrops http://t.co/fu3w5WvEDP   it   367592425              0  514343107823820800               0            0.000000                        iOS              Tuesday
# 1060                                                                           Visite d'altri tempi ;) Io &amp; Capagro.... Ahahhaha http://t.co/BybB5L2mar   it   367592425              0  514501968837234688               0            0.000000                   Facebook              Tuesday
# 1061                                                                                                      @LaforgiaLuca vedi un poco http://t.co/qYVBiilm3S   it   367592425              0  514502287382024192               0            0.000000         Twitter for iPhone              Tuesday
# 1062                                                                                                                                 http://t.co/3kr0EBq4rn  und   367592425              0  514929923845525504               0            0.000000                   Facebook             Thursday
# 1063                                         Il discorso di Matteo Renzi a New York così come l'ha capito un americano | VICE Italia http://t.co/9qV5tJpQe4   it   367592425              0  515202517265702912               0            0.000000       Twitter for Websites             Thursday
# 1069                                                                                                                                      ONTARIO #cslc2014   pt   628858971              0  515156697434689536               0                 NaN         Twitter for iPhone             Thursday
# 1128                                                                                                                                      Kik me Kishalove_   ht   451658694              0  515922276945248256               0                 NaN        Twitter for Android             Saturday
# 1156                                                                                                                      LMAOO #esu http://t.co/XpXoMCD1FB   ht  2279660855              0  515515265925533697               0            0.000000         Twitter for iPhone               Friday
# 1167                                                                                                                                @annna_evelyn oculus 😳😳  und   102262916              0  515404429286469632               0                 NaN         Twitter for iPhone               Friday
# 1170                                                                                                                                  @annna_evelyn yesssss  und   102262916              0  515507566848528384               0                 NaN         Twitter for iPhone               Friday
# 1187                                                                                                                                     @Pies_N_Thighs ite  und   378357896              0  514999138002669568               0                 NaN         Twitter for iPhone             Thursday
# 1201                                                                                                                              😎😎 http://t.co/7GdxYqmVdu  und   360752012              0  515597135916851200               0            0.000000                  Instagram               Friday
# 1212                                                                                                                                                #hunnid  und   274176474              0  515916061351243776               0                 NaN         Twitter for iPhone             Saturday
# 1248                                                                                      #BattleZone\n#REKO\n#WaitOnIt\n#October4th http://t.co/gbTr4yGLs2  und   626912116              1  514845568519389184               1            0.000000                  Instagram            Wednesday

# %%
df_tweets.user_id.unique().shape
# Out:
# (2195,)

# %%
df_tweets['tweet_length'] =df_tweets['text'].apply(lambda x: len(x))

# %% [markdown]
# <font size=4> <b> <p>Extracting Tweet Sentiments </p>
#
#     For example: Three new features can be created per user such as:
#     1. Number_of_positive_Tweets
#     2. Number_of_negative_Tweets
#     3. Number_of_neutral_Tweets

# %% [markdown]
# <font size=4>
#
# In Real Project Implementation, A NLP Sentiments Analysis model will need to be developed to classify a text into a sentiment. In other words, following will be the data requirements:-
#
#
# For the purpose of this assignment, I am using a combination of TextBlob and Vader libraries to classify the Tweet content since there is no tweet training data given (Twitter data is not labelled. hence cannot be used for training).
#
# These two libraries are pre-trained sentiment analysis models. If I do not use this library then I will have to create a labelled tweets manually and then trained a model which will be very time consuming and out of the scope of this project.
#
# Use NLTK Vader and TextBlob library to do tweet text sentimental analyis

# %%
# !pip install TextBlob
# Out:
# Requirement already satisfied: TextBlob in /opt/anaconda3/lib/python3.7/site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /opt/anaconda3/lib/python3.7/site-packages (from TextBlob) (3.4.5)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.7/site-packages (from nltk>=3.1->TextBlob) (1.14.0)

# %%
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in /opt/anaconda3/lib/python3.7/site-packages (3.3.2)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.7/site-packages (from vaderSentiment) (2.22.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests->vaderSentiment) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests->vaderSentiment) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/anaconda3/lib/python3.7/site-packages (from requests->vaderSentiment) (1.25.11)

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jatin.malhotra/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob
def evaluate_sentiments(p_txt):

    
    text_tb = TextBlob(p_txt)

    analyzer = SentimentIntensityAnalyzer()
    text_vs = analyzer.polarity_scores(p_txt)
    
    
    if text_tb.sentiment.polarity <= 0 and text_vs['compound'] <= -0.5:
        sentiment = "negative"  # very negative
    elif text_tb.sentiment.polarity <= 0 and text_vs['compound'] <= -0.1:
        sentiment = "negative"  # somewhat negative
    elif text_tb.sentiment.polarity == 0 and text_vs['compound'] > -0.1 and text_vs['compound'] < 0.1:
        sentiment = "neutral"
    elif text_tb.sentiment.polarity >= 0 and text_vs['compound'] >= 0.1:
        sentiment = "positive"  # somewhat positive
    elif text_tb.sentiment.polarity > 0 and text_vs['compound'] >= 0.1:
        sentiment = "positive"  # very positive
    else:
        sentiment = "neutral"
   
    polarity = (text_tb.sentiment.polarity + text_vs['compound']) / 2
   
    
    if  sentiment == 'negative':
        return 1, 0, 0
    elif sentiment == 'positive':
        return 0, 0, 1
    else:
        return 0, 1, 0

# %%
evaluate_sentiments("I am not so sad")
# Out:
# (0, 1, 0)

# %%
#df_tweets['tweet_sentiment'] = df_tweets['text'].apply(lambda x: evaluate_sentiments(x))

df_tweets['negative_sentiment'],df_tweets['neutral_sentiment'], df_tweets['positive_sentiment']  = zip(*df_tweets['text'].apply(lambda x: evaluate_sentiments(x)))

# %%
df_user_profile[df_user_profile.id==612815277]
# Out:
#                         entities profile_link_color    utc_offset    name  favourites_count  contributors_enabled  notifications location  protected lang profile_text_color         id  friends_count   url  default_profile_image                  profile_background_image_url_https  follow_request_sent  is_translation_enabled                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         status     id_str                                                       profile_image_url_https  profile_background_tile                created_at profile_background_color  statuses_count      screen_name                             description profile_sidebar_border_color  profile_use_background_image                                          profile_banner_url  geo_enabled  following  default_profile  is_translator  verified                                                            profile_image_url  followers_count                       profile_background_image_url profile_sidebar_fill_color  listed_count               time_zone
# 0  {'description': {'urls': []}}             009999 -10800.000000  Greggy              7931                 False          False               False   en             333333  612815277            264  None                  False  https://abs.twimg.com/images/themes/theme14/bg.gif                False                   False  {'retweeted_status': {'retweet_count': 452, 'created_at': 'Fri Sep 26 16:48:59 +0000 2014', 'id_str': '515543565683146752', 'favorited': False, 'coordinates': None, 'in_reply_to_user_id': None, 'text': 'Wow
#            So friday
#     Much happy
#       Such rejoice
#          Very excite
#  #thankdogeitsfriday
#      Amaze', 'favorite_count': 296, 'contributors': None, 'retweeted': False, 'entities': {'urls': [], 'user_mentions': [], 'symbols': [], 'hashtags': [{'indices': [81, 100], 'text': 'thankdogeitsfriday'}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_screen_name': None, 'id': 515543565683146752, 'place': None, 'geo': None, 'in_reply_to_user_id_str': None, 'truncated': False, 'in_reply_to_status_id_str': None, 'in_reply_to_status_id': None, 'lang': 'en'}, 'retweet_count': 452, 'favorited': False, 'text': 'RT @DogeTheDog: Wow
#            So friday
#     Much happy
#       Such rejoice
#          Very excite
#  #thankdogeitsfriday
#      Amaze', 'contributors': None, 'entities': {'urls': [], 'user_mentions': [{'id': 1591956090, 'screen_name': 'DogeTheDog', 'id_str': '1591956090', 'name': 'Doge', 'indices': [3, 14]}], 'symbols': [], 'hashtags': [{'indices': [97, 116], 'text': 'thankdogeitsfriday'}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id_str': None, 'id': 515543724785684480, 'geo': None, 'lang': 'en', 'id_str': '515543724785684480', 'created_at': 'Fri Sep 26 16:49:37 +0000 2014', 'in_reply_to_user_id': None, 'coordinates': None, 'favorite_count': 0, 'retweeted': False, 'in_reply_to_screen_name': None, 'place': None, 'in_reply_to_user_id_str': None, 'truncated': False, 'in_reply_to_status_id': None}  612815277  https://pbs.twimg.com/profile_images/477666282871861249/Z62rKDZE_normal.jpeg                     True 2012-06-19 17:54:58+00:00                   131516           12230  agregtoremember  You'll never find another one like me.                       EEEEEE                          True  https://pbs.twimg.com/profile_banners/612815277/1400624131         True      False            False          False     False  http://pbs.twimg.com/profile_images/477666282871861249/Z62rKDZE_normal.jpeg              274  http://abs.twimg.com/images/themes/theme14/bg.gif                     EFEFEF             1  Atlantic Time (Canada)

# %%
df_tweets.rename(columns={'retweet_count':'tweets_retweet_count',
                         'favorite_count':'tweets_favorite_count'}, inplace=True)

# %%
df_tweets[df_tweets.user_id==612815277]
# Out:
#                                                                                                                                      text lang    user_id  tweets_retweet_count                  id  tweets_favorite_count  possibly_sensitive        source_parsed creation_day_of_week  tweet_length  negative_sentiment  neutral_sentiment  positive_sentiment
# 0                                                                 RT @AlenaBacalia: i over think and second guess everything way too much   en  612815277                     7  515379174454747136                      0                 NaN   Twitter for iPhone               Friday            71                   0                  1                   0
# 1                                                                           RT @hfholden34: I've wasted too much time on the wrong people   en  612815277                    80  515379813670854656                      0                 NaN   Twitter for iPhone               Friday            61                   1                  0                   0
# 2                                                                                                                       I'm already gone.   en  612815277                     1  515380190361288704                      1                 NaN   Twitter for iPhone               Friday            17                   0                  1                   0
# 3                                                                   I'm already something to someone that I don't know. When will I know?   en  612815277                     0  515380273005854721                      1                 NaN   Twitter for iPhone               Friday            69                   0                  1                   0
# 4                                                   I don't know what I'm doing with my life, but all I know if that I'm doing it for me.   en  612815277                     0  515412946608852992                      1                 NaN  Twitter for Android               Friday            85                   0                  1                   0
# 5                                                                                     @MarilynYousif I was born without wisdom teeth... 😏   en  612815277                     0  515533004366565377                      1                 NaN   Twitter for iPhone               Friday            51                   1                  0                   0
# 6                                                                               RT @heeeeyerin: Beautiful things don't ask for attention.   en  612815277                     1  515533938018643971                      0                 NaN   Twitter for iPhone               Friday            57                   0                  0                   1
# 7                                                                                             Tubby's is the greatest hangover food ever.   en  612815277                     0  515542893319454721                      3                 NaN  Twitter for Android               Friday            43                   0                  0                   1
# 8   RT @DogeTheDog: Wow\n           So friday\n    Much happy\n      Such rejoice\n         Very excite\n #thankdogeitsfriday\n     Amaze   en  612815277                   526  515543724785684480                      0                 NaN  Twitter for Android               Friday           127                   0                  0                   1
# 9       Ever just stop and think about what your life would be like if you were still dating someone you were with when you were younger?   en  612815277                     2  515727608940863488                      4                 NaN  Twitter for Android             Saturday           129                   0                  1                   0
# 10                                                             Late night drives on the freeway are so relaxing and peaceful and awesome.   en  612815277                     0  515729460000468992                      1                 NaN  Twitter for Android             Saturday            74                   0                  0                   1
# 11                                                                                                        I miss the person I used to be.   en  612815277                     0  515732160100433920                      2                 NaN  Twitter for Android             Saturday            31                   1                  0                   0
# 12                                                                                     RT @MrJeffJ: Why can't I feel anything from anyone   en  612815277                     4  515740874811006976                      0                 NaN   Twitter for iPhone             Saturday            50                   0                  1                   0
# 13                                                                                        RT @LindsayGorncy: Let's clinch tonight @tigers   en  612815277                     1  515924835822612480                      0                 NaN  Twitter for Android             Saturday            47                   0                  1                   0

# %% [markdown]
# <font size=4> <b> EMOJI's FEATURES CREATION

# %% [markdown]
# <font size=4> <b> <p>Number of Emoji's used in a Tweet: EMOJIS_COUNT

# %%
# !pip install emoji
# Out:
# Requirement already satisfied: emoji in /opt/anaconda3/lib/python3.7/site-packages (1.7.0)

# %%
import emoji
import regex

def count_emojis(text):

    e_list = []
    data = regex.findall(r'\X', text)
    for word in data:
        if any(char in emoji.UNICODE_EMOJI['en'] for char in word):
            e_list.append(word)
    
    return len(e_list)

# %%
df_tweets['emojis_count'] = df_tweets['text'].apply(lambda x: count_emojis(x))

# %% [markdown]
# <font size=4> <b> <p>Extract Sentiments out of Emoji's. </p>
#
#     For example: Three new features can be created per user such as:
#     1. Number_of_positive_emojis
#     2. Number_of_negative_emojis
#     3. Number_of_neutral_emojis
#
#
# Example is shown below, but skipping this piece in the interest of time as it is similar to Tweet Sentiment Extraction

# %%
# !pip install emosent-py
# Out:
# Requirement already satisfied: emosent-py in /opt/anaconda3/lib/python3.7/site-packages (0.1.6)

# %%
from emosent import get_emoji_sentiment_rank
get_emoji_sentiment_rank('😩')['sentiment_score']
# Out:
# -0.368

# %%
df_tweets.head(2)
# Out:
#                                                                       text lang    user_id  tweets_retweet_count                  id  tweets_favorite_count  possibly_sensitive       source_parsed creation_day_of_week  tweet_length  negative_sentiment  neutral_sentiment  positive_sentiment  emojis_count
# 0  RT @AlenaBacalia: i over think and second guess everything way too much   en  612815277                     7  515379174454747136                      0                 NaN  Twitter for iPhone               Friday            71                   0                  1                   0             0
# 1            RT @hfholden34: I've wasted too much time on the wrong people   en  612815277                    80  515379813670854656                      0                 NaN  Twitter for iPhone               Friday            61                   1                  0                   0             0

# %%
df_tweets.possibly_sensitive.value_counts(dropna=False)
# Out:
# NaN         19970
# 0.000000     7998
# 1.000000      170
# Name: possibly_sensitive, dtype: int64

# %%
df_tweets['possibly_sensitive'] = df_tweets['possibly_sensitive'].fillna(-1)

# %%
df_tweets = df_tweets.groupby('user_id',as_index=False)\
                                     .agg({
                                            'lang': lambda x: x.value_counts().index[0],
                                            'tweets_retweet_count':'mean',
                                            'tweets_favorite_count': 'mean',
                                            'possibly_sensitive': lambda x: x.value_counts().index[0],
                                            'source_parsed': lambda x: x.value_counts().index[0],
                                            'creation_day_of_week': lambda x: x.value_counts().index[0],
                                            'tweet_length': 'mean',
                                            'negative_sentiment': 'sum',
                                            'neutral_sentiment': 'sum',
                                            'positive_sentiment': 'sum',
                                            'emojis_count': 'sum',
                                          }
                                         )

# %%
df_tweets[df_tweets.user_id==25762322]
# Out:
#      user_id lang  tweets_retweet_count  tweets_favorite_count  possibly_sensitive source_parsed creation_day_of_week  tweet_length  negative_sentiment  neutral_sentiment  positive_sentiment  emojis_count
# 59  25762322  und              0.000000               0.000000            0.000000     Instagram             Saturday     57.666667                   0                  2                   1             0

# %% [markdown]
# <font size = 4><b> ***** TWEET OBJECT EDA ENDS *****

# %% [markdown]
# <font size = 4><b> USER PROFILE OBJECT EDA

# %%
df_user_profile.head(1)
# Out:
#                         entities profile_link_color    utc_offset    name  favourites_count  contributors_enabled  notifications location  protected lang profile_text_color         id  friends_count   url  default_profile_image                  profile_background_image_url_https  follow_request_sent  is_translation_enabled                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         status     id_str                                                       profile_image_url_https  profile_background_tile                created_at profile_background_color  statuses_count      screen_name                             description profile_sidebar_border_color  profile_use_background_image                                          profile_banner_url  geo_enabled  following  default_profile  is_translator  verified                                                            profile_image_url  followers_count                       profile_background_image_url profile_sidebar_fill_color  listed_count               time_zone
# 0  {'description': {'urls': []}}             009999 -10800.000000  Greggy              7931                 False          False               False   en             333333  612815277            264  None                  False  https://abs.twimg.com/images/themes/theme14/bg.gif                False                   False  {'retweeted_status': {'retweet_count': 452, 'created_at': 'Fri Sep 26 16:48:59 +0000 2014', 'id_str': '515543565683146752', 'favorited': False, 'coordinates': None, 'in_reply_to_user_id': None, 'text': 'Wow
#            So friday
#     Much happy
#       Such rejoice
#          Very excite
#  #thankdogeitsfriday
#      Amaze', 'favorite_count': 296, 'contributors': None, 'retweeted': False, 'entities': {'urls': [], 'user_mentions': [], 'symbols': [], 'hashtags': [{'indices': [81, 100], 'text': 'thankdogeitsfriday'}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_screen_name': None, 'id': 515543565683146752, 'place': None, 'geo': None, 'in_reply_to_user_id_str': None, 'truncated': False, 'in_reply_to_status_id_str': None, 'in_reply_to_status_id': None, 'lang': 'en'}, 'retweet_count': 452, 'favorited': False, 'text': 'RT @DogeTheDog: Wow
#            So friday
#     Much happy
#       Such rejoice
#          Very excite
#  #thankdogeitsfriday
#      Amaze', 'contributors': None, 'entities': {'urls': [], 'user_mentions': [{'id': 1591956090, 'screen_name': 'DogeTheDog', 'id_str': '1591956090', 'name': 'Doge', 'indices': [3, 14]}], 'symbols': [], 'hashtags': [{'indices': [97, 116], 'text': 'thankdogeitsfriday'}]}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id_str': None, 'id': 515543724785684480, 'geo': None, 'lang': 'en', 'id_str': '515543724785684480', 'created_at': 'Fri Sep 26 16:49:37 +0000 2014', 'in_reply_to_user_id': None, 'coordinates': None, 'favorite_count': 0, 'retweeted': False, 'in_reply_to_screen_name': None, 'place': None, 'in_reply_to_user_id_str': None, 'truncated': False, 'in_reply_to_status_id': None}  612815277  https://pbs.twimg.com/profile_images/477666282871861249/Z62rKDZE_normal.jpeg                     True 2012-06-19 17:54:58+00:00                   131516           12230  agregtoremember  You'll never find another one like me.                       EEEEEE                          True  https://pbs.twimg.com/profile_banners/612815277/1400624131         True      False            False          False     False  http://pbs.twimg.com/profile_images/477666282871861249/Z62rKDZE_normal.jpeg              274  http://abs.twimg.com/images/themes/theme14/bg.gif                     EFEFEF             1  Atlantic Time (Canada)

# %%
df_user_profile.shape
# Out:
# (2410, 41)

# %%
df_user_profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 41 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   entities                            2410 non-null   object
#  1   profile_link_color                  2410 non-null   object
#  2   utc_offset                          1697 non-null   float64
#  3   name                                2410 non-null   object
#  4   favourites_count                    2410 non-null   int64
#  5   contributors_enabled                2410 non-null   bool
#  6   notifications                       2410 non-null   bool
#  7   location                            2410 non-null   object
#  8   protected                           2410 non-null   bool
#  9   lang                                2410 non-null   object
#  10  profile_text_color                  2410 non-null   object
#  11  id                                  2410 non-null   int64
#  12  friends_count                       2410 non-null   int64
#  13  url                                 550 non-null    object
#  14  default_profile_image               2410 non-null   bool
#  15  profile_background_image_url_https  2410 non-null   object
#  16  follow_request_sent                 2410 non-null   bool
#  17  is_translation_enabled              2410 non-null   bool
#  18  status                              2373 non-null   object
#  19  id_str                              2410 non-null   int64
#  20  profile_image_url_https             2410 non-null   object
#  21  profile_background_tile             2410 non-null   bool
#  22  created_at                          2410 non-null   datetime64[ns, UTC]
#  23  profile_background_color            2410 non-null   object
#  24  statuses_count                      2410 non-null   int64
#  25  screen_name                         2410 non-null   object
#  26  description                         2410 non-null   object
#  27  profile_sidebar_border_color        2410 non-null   object
#  28  profile_use_background_image        2410 non-null   bool
#  29  profile_banner_url                  2191 non-null   object
#  30  geo_enabled                         2410 non-null   bool
#  31  following                           2410 non-null   bool
#  32  default_profile                     2410 non-null   bool
#  33  is_translator                       2410 non-null   bool
#  34  verified                            2410 non-null   bool
#  35  profile_image_url                   2410 non-null   object
#  36  followers_count                     2410 non-null   int64
#  37  profile_background_image_url        2410 non-null   object
#  38  profile_sidebar_fill_color          2410 non-null   object
#  39  listed_count                        2410 non-null   int64
#  40  time_zone                           1697 non-null   object
# dtypes: bool(13), datetime64[ns, UTC](1), float64(1), int64(7), object(19)
# memory usage: 557.9+ KB

# %%
df_user_profile.describe()
# Out:
#          utc_offset  favourites_count                id  friends_count            id_str  statuses_count  followers_count  listed_count
# count   1697.000000       2410.000000       2410.000000    2410.000000       2410.000000     2410.000000      2410.000000   2410.000000
# mean  -12402.710666       1800.120332  691827956.848133     689.358921  691827956.848133    16982.506224       944.855187      5.470124
# std    15420.244205       3884.458445  795375674.103617    4970.227333  795375674.103617    25033.534126      7083.829476     34.984290
# min   -39600.000000          0.000000    2025381.000000     -69.000000    2025381.000000        0.000000         0.000000      0.000000
# 25%   -18000.000000        103.000000  159298221.500000     179.000000  159298221.500000     1960.250000       160.000000      0.000000
# 50%   -18000.000000        543.000000  350802316.500000     340.000000  350802316.500000     7408.500000       348.000000      1.000000
# 75%   -10800.000000       1949.500000  880424268.750000     628.000000  880424268.750000    21565.250000       700.250000      3.000000
# max    43200.000000      99169.000000 2832494239.000000  202293.000000 2832494239.000000   257590.000000    258937.000000   1292.000000

# %%
df_user_profile.isna().sum().sort_values(ascending=False).to_frame().head(10)
# Out:
#                                  0
# url                           1860
# time_zone                      713
# utc_offset                     713
# profile_banner_url             219
# status                          37
# geo_enabled                      0
# statuses_count                   0
# screen_name                      0
# description                      0
# profile_sidebar_border_color     0

# %%
USER_FEATURES = ['id']

# %%
df_user_profile.geo_enabled.value_counts()
# Out:
# True     1211
# False    1199
# Name: geo_enabled, dtype: int64

# %%
USER_FEATURES.append('geo_enabled')

# %%
df_user_profile.profile_sidebar_border_color.value_counts().to_frame().head(10)
# Out:
#         profile_sidebar_border_color
# C0DEED                           737
# FFFFFF                           660
# 000000                           308
# EEEEEE                           148
# 65B0DA                            70
# 181A1E                            68
# CC3366                            49
# DBE9ED                            26
# 5ED4DC                            25
# F0A830                            20

# %%
USER_FEATURES.append('profile_sidebar_border_color')

# %%
df_user_profile.profile_use_background_image.value_counts()
# Out:
# True     2269
# False     141
# Name: profile_use_background_image, dtype: int64

# %%
'''
This feature does not make sense
'''
df_user_profile.following.value_counts()
# Out:
# False    2410
# Name: following, dtype: int64

# %%
df_user_profile.default_profile.value_counts()
# Out:
# False    1786
# True      624
# Name: default_profile, dtype: int64

# %%
USER_FEATURES.append('default_profile')

# %%
'''
This feature does not make sense
'''
df_user_profile.is_translator.value_counts()
# Out:
# False    2410
# Name: is_translator, dtype: int64

# %%
'''
This feature does not make sense
'''
df_user_profile.verified.value_counts()
# Out:
# False    2410
# Name: verified, dtype: int64

# %%
df_user_profile.followers_count.value_counts().to_frame().head(5)
# Out:
#      followers_count
# 122                9
# 181                8
# 179                8
# 18                 8
# 170                8

# %%
USER_FEATURES.append('followers_count')

# %%
df_user_profile.profile_sidebar_fill_color.value_counts().to_frame().head(10)
# Out:
#         profile_sidebar_fill_color
# DDEEF6                        1032
# EFEFEF                         153
# 7AC3EE                         121
# 252429                         110
# E5507E                          76
# F6F6F6                          76
# 000000                          75
# FFFFFF                          65
# 95E8EC                          38
# E6F6F9                          36

# %%
USER_FEATURES.append('profile_sidebar_fill_color')

# %%
df_user_profile.listed_count.value_counts().to_frame().head(10)
# Out:
#    listed_count
# 0          1056
# 1           455
# 2           265
# 3           164
# 4           107
# 5            52
# 6            40
# 7            27
# 8            23
# 9            23

# %%
USER_FEATURES.append('listed_count')

# %%
df_user_profile.profile_background_color.value_counts().to_frame().head(10)
# Out:
#         profile_background_color
# C0DEED                       874
# 131516                       155
# 000000                       132
# 642D8B                       110
# 1A1B1F                       109
# FFFFFF                        84
# FF6699                        74
# ACDED6                        66
# DBE9ED                        46
# 022330                        31

# %%
USER_FEATURES.append('profile_background_color')

# %%
df_user_profile.profile_background_tile.value_counts()
# Out:
# False    1249
# True     1161
# Name: profile_background_tile, dtype: int64

# %%
USER_FEATURES.append('profile_background_tile')

# %%
df_user_profile.contributors_enabled.value_counts()
# Out:
# False    2410
# Name: contributors_enabled, dtype: int64

# %%
USER_FEATURES.append('profile_link_color')

# %%
df_user_profile.contributors_enabled.value_counts()
# Out:
# False    2410
# Name: contributors_enabled, dtype: int64

# %%
df_user_profile.notifications.value_counts()
# Out:
# False    2410
# Name: notifications, dtype: int64

# %%
USER_FEATURES.append('location')

# %%
df_user_profile.lang.value_counts()
# Out:
# en       2334
# es         27
# en-gb      13
# id          5
# pt          5
# nl          5
# it          4
# ja          3
# en-GB       2
# ru          2
# de          1
# ar          1
# he          1
# fi          1
# xx-lc       1
# hu          1
# pl          1
# da          1
# fil         1
# fr          1
# Name: lang, dtype: int64

# %%
USER_FEATURES.append('profile_text_color')

# %%
df_user_profile.follow_request_sent.value_counts()
# Out:
# False    2410
# Name: follow_request_sent, dtype: int64

# %%
df_user_profile.is_translation_enabled.value_counts()
# Out:
# False    2407
# True        3
# Name: is_translation_enabled, dtype: int64

# %%
USER_FEATURES.append('friends_count')

# %%
USER_FEATURES
# Out:
# ['id',
#  'geo_enabled',
#  'profile_sidebar_border_color',
#  'default_profile',
#  'followers_count',
#  'profile_sidebar_fill_color',
#  'listed_count',
#  'profile_background_color',
#  'profile_background_tile',
#  'profile_link_color',
#  'location',
#  'profile_text_color',
#  'friends_count']

# %%
'''
Take first user mentioned in the tweet. Null if no user is mentioned
'''
df_user_profile['retweet_count'] = pd.json_normalize(df_user_profile.status)['retweet_count']

# %%
USER_FEATURES.append('retweet_count')

# %%
df_user_profile[USER_FEATURES].head(5)
# Out:
#           id  geo_enabled profile_sidebar_border_color  default_profile  followers_count profile_sidebar_fill_color  listed_count profile_background_color  profile_background_tile profile_link_color               location profile_text_color  friends_count  retweet_count
# 0  612815277         True                       EEEEEE            False              274                     EFEFEF             1                   131516                     True             009999                                    333333            264     452.000000
# 1  490791079         True                       181A1E            False              481                     252429             1                   1A1B1F                    False             2FC2EF                 9⃣3⃣7⃣             666666            527       0.000000
# 2  264416315        False                       F0A830            False              878                     78C0A8             2                   FCEBB6                     True             CE7834            Wonderland              5E412F            953    2614.000000
# 3   97515432        False                       FFFFFF            False              742                     EFEFEF            30                   131516                     True             009999  •Carolina South• 843•             333333            701       0.000000
# 4  271608323        False                       000000            False              729                     000000             0                   0A0A0A                     True             D62D0F       Seven•five•Seven             A3A3A3            688       0.000000

# %%
df_user_profile=df_user_profile[USER_FEATURES]

# %% [markdown]
# <font size = 4><b> ***** USER PROFILE EDA ENDS *****

# %% [markdown]
# <font size = 4><b> ***** MENTIONs and FRIENDs PROFILE EDA *****

# %% [markdown]
# Mentions and Friends Profile is a replica of User Object Profile which means similar EDA and Feature engineering applies so in the interest of time, I will skip exploring Mentoions and Friends profile data.
#
# In real project scenario, I will add friends and mentions related feature to User profiles dataframe but keeping it out of scope for the purpose of this assignment.

# %% [markdown]
# As "friends_count" is already a feature in df_user_profile, let's add mentions_count as another feature using mentions.csv

# %%
df_mentions_count.head(10)
# Out:
#             ID
# 315555817   51
# 2207254850  51
# 283449093   42
# 455777416   42
# 184928826   40
# 69856018    40
# 471401606   39
# 25953256    37
# 68877665    36
# 165163852   35

# %% [markdown]
# <font size = 4><b> Add Mentions Count to the User Profile data

# %%
df_user_profile = pd.merge(df_user_profile, df_mentions_count, left_on=['id'], right_on=['ID'], how='left')

# %%
df_user_profile[df_user_profile.id==315555817]
# Out:
#              id  geo_enabled profile_sidebar_border_color  default_profile  followers_count profile_sidebar_fill_color  listed_count profile_background_color  profile_background_tile profile_link_color                        location profile_text_color  friends_count  retweet_count               ID  mentions_count
# 1328  315555817        False                       FFFFFF            False             7105                     E6F6F9            52                   DBE9ED                    False             CC3366  Ass in Canada Heart in Poland!             333333           7688       0.000000 315555817.000000       51.000000

# %%
df_tweets.head(2)
# Out:
#     user_id lang  tweets_retweet_count  tweets_favorite_count  possibly_sensitive        source_parsed creation_day_of_week  tweet_length  negative_sentiment  neutral_sentiment  positive_sentiment  emojis_count
# 0   2025381   en              0.000000               0.000000           -1.000000   Twitter Web Client               Friday     53.785714                   1                  4                   9             0
# 1  14367721   en              0.000000               1.000000           -1.000000  Twitter for Android             Saturday     87.000000                   0                  1                   0             0

# %% [markdown]
# <font size = 4><b> Merge User and Tweet profiles

# %%
df = pd.merge(df_user_profile, df_tweets, left_on=['id'], right_on=['user_id'], how='left')

# %%
df.shape, df_user_profile.shape, df_tweets.shape
# Out:
# ((2410, 28), (2410, 16), (2195, 12))

# %%
df.head(5)
# Out:
#           id  geo_enabled profile_sidebar_border_color  default_profile  followers_count profile_sidebar_fill_color  listed_count profile_background_color  profile_background_tile profile_link_color               location profile_text_color  friends_count  retweet_count          user_id lang  tweets_retweet_count  tweets_favorite_count  possibly_sensitive        source_parsed creation_day_of_week  tweet_length  negative_sentiment  neutral_sentiment  positive_sentiment  emojis_count
# 0  612815277         True                       EEEEEE            False              274                     EFEFEF             1                   131516                     True             009999                                    333333            264     452.000000 612815277.000000   en             44.428571               1.000000           -1.000000   Twitter for iPhone               Friday     65.142857            3.000000           7.000000            4.000000      1.000000
# 1  490791079         True                       181A1E            False              481                     252429             1                   1A1B1F                    False             2FC2EF                 9⃣3⃣7⃣             666666            527       0.000000 490791079.000000   en            149.733333               0.000000           -1.000000   Twitter for iPhone               Friday     50.800000            3.000000           6.000000            6.000000      5.000000
# 2  264416315        False                       F0A830            False              878                     78C0A8             2                   FCEBB6                     True             CE7834            Wonderland              5E412F            953    2614.000000 264416315.000000   en           1523.450000               0.050000           -1.000000  Twitter for Android               Friday     82.450000            3.000000           9.000000            8.000000     19.000000
# 3   97515432        False                       FFFFFF            False              742                     EFEFEF            30                   131516                     True             009999  •Carolina South• 843•             333333            701       0.000000  97515432.000000   en              0.000000               0.000000            0.000000          Cloudhopper             Saturday     62.000000            0.000000           7.000000            7.000000      0.000000
# 4  271608323        False                       000000            False              729                     000000             0                   0A0A0A                     True             D62D0F       Seven•five•Seven             A3A3A3            688       0.000000 271608323.000000   en              0.200000               0.066667           -1.000000  Twitter for Android             Saturday     82.066667            3.000000           7.000000            5.000000      1.000000

# %%
df[df.user_id==612815277]
# Out:
#           id  geo_enabled profile_sidebar_border_color  default_profile  followers_count profile_sidebar_fill_color  listed_count profile_background_color  profile_background_tile profile_link_color location profile_text_color  friends_count  retweet_count               ID  mentions_count          user_id lang  tweets_retweet_count  tweets_favorite_count  possibly_sensitive       source_parsed creation_day_of_week  tweet_length  negative_sentiment  neutral_sentiment  positive_sentiment  emojis_count
# 0  612815277         True                       EEEEEE            False              274                     EFEFEF             1                   131516                     True             009999                      333333            264     452.000000 612815277.000000        8.000000 612815277.000000   en             44.428571               1.000000           -1.000000  Twitter for iPhone               Friday     65.142857            3.000000           7.000000            4.000000      1.000000

# %% [markdown]
# <font size = 4><b> Merge User Profile with user Train Data to Add Age(label) column to the dataset

# %%
df1 = pd.merge(df, df_ages_train, right_on='ID', left_on='user_id')

# %%
df.shape, df1.shape, df_ages_train.shape
# Out:
# ((2410, 28), (1544, 30), (1711, 2))

# %%
df1[df1.user_id==612815277]
# Out:
#           id  geo_enabled profile_sidebar_border_color  default_profile  followers_count profile_sidebar_fill_color  listed_count profile_background_color  profile_background_tile profile_link_color location profile_text_color  friends_count  retweet_count             ID_x  mentions_count          user_id lang  tweets_retweet_count  tweets_favorite_count  possibly_sensitive       source_parsed creation_day_of_week  tweet_length  negative_sentiment  neutral_sentiment  positive_sentiment  emojis_count       ID_y  Age
# 0  612815277         True                       EEEEEE            False              274                     EFEFEF             1                   131516                     True             009999                      333333            264     452.000000 612815277.000000        8.000000 612815277.000000   en             44.428571               1.000000           -1.000000  Twitter for iPhone               Friday     65.142857            3.000000           7.000000            4.000000      1.000000  612815277   21

# %%
df1.drop(columns=['id','ID_x'], inplace=True)

# %%
df1.head(10)
# Out:
#    geo_enabled profile_sidebar_border_color  default_profile  followers_count profile_sidebar_fill_color  listed_count profile_background_color  profile_background_tile profile_link_color               location profile_text_color  friends_count  retweet_count  mentions_count          user_id lang  tweets_retweet_count  tweets_favorite_count  possibly_sensitive        source_parsed creation_day_of_week  tweet_length  negative_sentiment  neutral_sentiment  positive_sentiment  emojis_count       ID_y  Age
# 0         True                       EEEEEE            False              274                     EFEFEF             1                   131516                     True             009999                                    333333            264     452.000000        8.000000 612815277.000000   en             44.428571               1.000000           -1.000000   Twitter for iPhone               Friday     65.142857            3.000000           7.000000            4.000000      1.000000  612815277   21
# 1         True                       181A1E            False              481                     252429             1                   1A1B1F                    False             2FC2EF                 9⃣3⃣7⃣             666666            527       0.000000        9.000000 490791079.000000   en            149.733333               0.000000           -1.000000   Twitter for iPhone               Friday     50.800000            3.000000           6.000000            6.000000      5.000000  490791079   18
# 2        False                       F0A830            False              878                     78C0A8             2                   FCEBB6                     True             CE7834            Wonderland              5E412F            953    2614.000000       16.000000 264416315.000000   en           1523.450000               0.050000           -1.000000  Twitter for Android               Friday     82.450000            3.000000           9.000000            8.000000     19.000000  264416315   18
# 3        False                       FFFFFF            False              742                     EFEFEF            30                   131516                     True             009999  •Carolina South• 843•             333333            701       0.000000             NaN  97515432.000000   en              0.000000               0.000000            0.000000          Cloudhopper             Saturday     62.000000            0.000000           7.000000            7.000000      0.000000   97515432   23
# 4         True                       FFFFFF            False             1030                     DDEEF6             3                   642D8B                     True             FF0091                     ME             333333           1006       0.000000        8.000000 224078321.000000   en            134.466667               0.000000           -1.000000  Twitter for Android             Saturday     57.866667            5.000000           7.000000            3.000000      5.000000  224078321   18
# 5        False                       DBE9ED            False             1025                     E6F6F9            10                   DBE9ED                     True             CC3366                                    333333           1049       0.000000       11.000000 314345007.000000   en              0.500000               0.642857           -1.000000   Twitter for iPhone               Sunday     41.214286            2.000000           8.000000            4.000000     18.000000  314345007   24
# 6        False                       FFFFFF            False              234                     FFFFFF             0                   7B338A                     True             BF4598                                    333333            220       1.000000        5.000000 249775709.000000   en              0.333333               1.222222           -1.000000   Twitter for iPhone             Saturday     61.444444            1.000000           6.000000            2.000000      1.000000  249775709   21
# 7         True                       FFFFFF            False             1016                     030101             1                   000000                     True             5C5C5C                                    FF0015            837       0.000000       12.000000 247434515.000000   en              0.600000               0.066667           -1.000000   Twitter for iPhone            Wednesday     54.200000            7.000000           7.000000            1.000000     25.000000  247434515   22
# 8         True                       DBE9ED            False             1218                     E6F6F9             4                   DBE9ED                    False             CC3366                8/10/13             333333            724       0.000000        7.000000 400908342.000000   en              0.400000               0.200000           -1.000000    Plume for Android             Saturday     57.450000            8.000000           4.000000            8.000000     23.000000  400908342   20
# 9         True                       FFFFFF            False              543                     DDEEF6             0                   FFFFFF                    False             000000                                    333333             50       0.000000             NaN 446663800.000000   en              0.000000               0.333333            0.000000            Instagram               Friday     68.666667            0.000000           3.000000            0.000000      7.000000  446663800   22

# %%
cat_features=[]
for c_idx, c in enumerate(df1.columns):
    col_type = df1[c].dtype
    if col_type == 'object' or col_type.name == 'category':
        df1[c] = df1[c].astype('category')
        cat_features.append(c_idx)

# %%
df1.dtypes
# Out:
# geo_enabled                         bool
# profile_sidebar_border_color    category
# default_profile                     bool
# followers_count                    int64
# profile_sidebar_fill_color      category
# listed_count                       int64
# profile_background_color        category
# profile_background_tile             bool
# profile_link_color              category
# location                        category
# profile_text_color              category
# friends_count                      int64
# retweet_count                    float64
# mentions_count                   float64
# user_id                          float64
# lang                            category
# tweets_retweet_count             float64
# tweets_favorite_count            float64
# possibly_sensitive               float64
# source_parsed                   category
# creation_day_of_week            category
# tweet_length                     float64
# negative_sentiment               float64
# neutral_sentiment                float64
# positive_sentiment               float64
# emojis_count                     float64
# ID_y                               int64
# Age                                int64
# dtype: object

# %%
df1.default_profile.value_counts().plot(kind='barh', figsize=(10,4), color='b')

# %%
distribution_plot(df1, 'followers_count')

# %%
distribution_plot(df1, 'listed_count')

# %%
distribution_plot(df1, 'friends_count')

# %%
df1.retweet_count.describe()
# Out:
# count    1541.000000
# mean      305.378975
# std      2155.180450
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max     40111.000000
# Name: retweet_count, dtype: float64

# %%
df1.shape
# Out:
# (1544, 27)

# %%
df2.head(3)
# Out:
# Empty DataFrame
# Columns: [geo_enabled, profile_sidebar_border_color, default_profile, followers_count, profile_sidebar_fill_color, listed_count, profile_background_color, profile_background_tile, profile_link_color, location, profile_text_color, friends_count, retweet_count, user_id, lang, tweets_retweet_count, tweets_favorite_count, possibly_sensitive, source_parsed, creation_day_of_week, tweet_length, negative_sentiment, neutral_sentiment, positive_sentiment, emojis_count, ID, Age]
# Index: []

# %%
from scipy import stats
from scipy.stats import norm, skew
import numpy as np

def outlier_removal(df:pd.DataFrame, col):
    """
    input: dataframe
    purpose: removes outliers > 4 STD
    output: dataframe
    """
    z_scores = stats.zscore(df[{col}])
    abs_z_scores = np.abs(z_scores)

    filtered_entries = (abs_z_scores < 4).all(axis=1)
    outliers=(abs_z_scores >= 4).all(axis=1)
    df = df[filtered_entries]
    return df

def log_transformation(df:pd.DataFrame, cols_list):
    """
    input: dataframe
    purpose: log transformation
    output: dataframe
    """
    for col in cols_list:
        df.loc[:,col] = df[col].apply(lambda x: np.log1p(x))

    return df

# %%
df1 = outlier_removal(df1, 'Age')

# %%
df1 = outlier_removal(df1, 'friends_count')

# %%
df1 = outlier_removal(df1, 'listed_count')

# %%
distribution_plot(df1, 'Age')

# %%
distribution_plot(df1, 'friends_count')

# %%
distribution_plot(df1, 'listed_count')

# %%
df1.shape, df2.shape
# Out:
# ((1511, 28), (1527, 27))

# %%
df1 = log_transformation(df1, ['followers_count', 'listed_count', 'friends_count','retweet_count',
                               'tweets_retweet_count','tweets_favorite_count','tweet_length',
                               'emojis_count'
                              ])

# %%
df1 = log_transformation(df1,['Age'])

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20,20))
sns.heatmap(df1.corr('spearman'), square=True, annot=True, cmap='Reds',linecolor="black", linewidths=0.20)
plt.show()

# %%
def bool_to_vec(df, cols):
    
    for col in cols:
        
        if df[col].dtypes == bool:
            
            df.loc[:,col] = df[col].apply(lambda x: 1 if x else 0)
            
    return df

# %%
df1 = bool_to_vec(df1, ['geo_enabled','default_profile','profile_background_tile'])

# %%
df1.head(5)
# Out:
#    geo_enabled profile_sidebar_border_color  default_profile  followers_count profile_sidebar_fill_color  listed_count profile_background_color  profile_background_tile profile_link_color               location profile_text_color  friends_count  retweet_count             ID_x  mentions_count          user_id lang  tweets_retweet_count  tweets_favorite_count  possibly_sensitive        source_parsed creation_day_of_week  tweet_length  negative_sentiment  neutral_sentiment  positive_sentiment  emojis_count       ID_y      Age
# 0            1                       EEEEEE                0         5.616771                     EFEFEF      0.693147                   131516                        1             009999                                    333333       5.579730       6.115892 612815277.000000        8.000000 612815277.000000   en              3.816141               0.693147           -1.000000   Twitter for iPhone               Friday      4.191817            3.000000           7.000000            4.000000      0.693147  612815277 3.091042
# 1            1                       181A1E                0         6.177944                     252429      0.693147                   1A1B1F                        0             2FC2EF                 9⃣3⃣7⃣             666666       6.269096       0.000000 490791079.000000        9.000000 490791079.000000   en              5.015512               0.000000           -1.000000   Twitter for iPhone               Friday      3.947390            3.000000           6.000000            6.000000      1.791759  490791079 2.944439
# 2            0                       F0A830                0         6.778785                     78C0A8      1.098612                   FCEBB6                        1             CE7834            Wonderland              5E412F       6.860664       7.869019 264416315.000000       16.000000 264416315.000000   en              7.329389               0.048790           -1.000000  Twitter for Android               Friday      4.424248            3.000000           9.000000            8.000000      2.995732  264416315 2.944439
# 3            0                       FFFFFF                0         6.610696                     EFEFEF      3.433987                   131516                        1             009999  •Carolina South• 843•             333333       6.553933       0.000000              NaN             NaN  97515432.000000   en              0.000000               0.000000            0.000000          Cloudhopper             Saturday      4.143135            0.000000           7.000000            7.000000      0.000000   97515432 3.178054
# 4            1                       FFFFFF                0         6.938284                     DDEEF6      1.386294                   642D8B                        1             FF0091                     ME             333333       6.914731       0.000000 224078321.000000        8.000000 224078321.000000   en              4.908726               0.000000           -1.000000  Twitter for Android             Saturday      4.075275            5.000000           7.000000            3.000000      1.791759  224078321 2.944439

# %%
df1.isna().sum()
# Out:
# geo_enabled                       0
# profile_sidebar_border_color      0
# default_profile                   0
# followers_count                   0
# profile_sidebar_fill_color        0
# listed_count                      0
# profile_background_color          0
# profile_background_tile           0
# profile_link_color                0
# location                          0
# profile_text_color                0
# friends_count                     0
# retweet_count                     3
# mentions_count                  180
# user_id                           0
# lang                              0
# tweets_retweet_count              0
# tweets_favorite_count             0
# possibly_sensitive                0
# source_parsed                     0
# creation_day_of_week              0
# tweet_length                      0
# negative_sentiment                0
# neutral_sentiment                 0
# positive_sentiment                0
# emojis_count                      0
# ID_y                              0
# Age                               0
# dtype: int64

# %%
df1.loc[:,'friends_count'] =df1['friends_count'].fillna(0)
df1.loc[:,'retweet_count'] =df1['retweet_count'].fillna(0)
df1.loc[:,'mentions_count'] =df1['retweet_count'].fillna(0)

# %%
df1.loc[:,'location'] = df1['location'].apply(lambda x: 'unknown' if x=='' else x)

# %%
import category_encoders as ce
from sklearn.pipeline import Pipeline

from lightgbm import LGBMRegressor, LGBMClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb

# %%
from datetime import datetime

start_time = datetime.now()

import category_encoders as ce
from sklearn.pipeline import Pipeline

from lightgbm import LGBMRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.linear_model import LassoCV
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import PolynomialFeatures
import xgboost as xgb
from catboost import CatBoostRegressor

y=df1['Age']
X=df1.drop(columns=['Age','user_id'])



# TEST/TRAIN
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)




cat_vars=[ 'creation_day_of_week',
            'profile_sidebar_border_color',  
            'profile_sidebar_fill_color',   
            'profile_background_color',     
            'profile_link_color',       
            'location',             
            'profile_text_color',              
            'lang',             
            'source_parsed',                   
            'creation_day_of_week'
         ]
          




hyper_params ={'learning_rate': 0.1, 
               'boosting_type': 'gbdt', 
              # 'sub_feature': 0.17324297024920832, 
              # 'num_leaves': 500, 
              # 'min_child_weight':1e-05,
              # 'min_child_samples': 40,
              # 'min_data': 314,
              # 'max_depth': 50,
               'random_state':0,
               'reg_alpha':1,
               'reg_lambda':1
              }




pipeline=Pipeline([
            #('campaignTrans',CampaignTransformer()),
            ('target',ce.TargetEncoder(cols=cat_vars, handle_missing='value',handle_unknown='value',smoothing=5)),
            #('target',ce.LeaveOneOutEncoder(cols=cat_vars, sigma=0.05)),
            #('onehot',ce.OneHotEncoder(cols=cat_vars)),
            #('training',LGBMRegressor(**hyper_params))
           # ('training',LGBMRegressor(random_state=0))
            #('training',LGBMClassifier(random_state=0))
           # ('training',LGBMClassifier(**hyper_params)) 
            #('training',DecisionTreeRegressor())
             #('training',SVR(kernel='sigmoid'))
            #('lasso', LassoCV())
            #('training',RandomForestRegressor(**rf_hyper_params))
            #('training',RandomForestRegressor(random_state=0))
            #('training',RandomForestRegressor(n_estimators=100))
            #('plf',PolynomialFeatures(degree=4)),
            #('training',LinearRegression())
            ('training',xgb.XGBRegressor(random_state=0))
            # ('training',xgb.XGBClassifier(random_state=0))
             ]
          )
                            
model_reg=pipeline.fit(X_train,y_train)


y_pred=model_reg.predict(X_test)

#X_test['predicted_acs_margin']=y_pred
#X_test['acs_margin']=y_test


X_test['actual_age']=y_test
X_test['predicted_age']=y_pred

print('Duration: {}'.format(datetime.now() - start_time))
# Out:
# Duration: 0:00:00.239727

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# sorted(zip(clf.feature_importances_, X.columns), reverse=True)
feature_imp = pd.DataFrame(sorted(zip(model_reg.named_steps["training"].feature_importances_,X_train.columns)), columns=['Value','Feature'])


plt.figure(figsize=(20, 20))
sns.barplot(x="Value", y="Feature", data=feature_imp.sort_values(by="Value", ascending=False))
plt.title('Feature Importance')
plt.tight_layout()
plt.show()

# %%
ig, ax = plt.subplots(figsize=(10,10))


ax.scatter(X_test['actual_age'], X_test['predicted_age'])
ax.plot([X_test['predicted_age'].min(), X_test['predicted_age'].max()+1], [X_test['predicted_age'].min(), X_test['predicted_age'].max()+1], 'k--', lw=4)
ax.set_xlabel('Actual Age')
ax.set_ylabel('Predicted Age')
plt.show()

# %%
X_test.loc[:,'actual_age_orig'] = X_test['actual_age'].apply(lambda x: np.expm1(x))


X_test.loc[:,'predicted_age_orig'] = X_test['predicted_age'].apply(lambda x: np.expm1(x))

# %%
import numpy as np
X_test.loc[:,'actual_adj'] = X_test['actual_age']  + 0.1* X_test['actual_age'].std()**2
X_test.loc[:,'actual_adj'] = X_test['actual_age'].apply(lambda x: np.expm1(x))


X_test.loc[:,'predicted_age_adj'] = X_test['predicted_age']  + 0.1* X_test['predicted_age'].std()**2
X_test.loc[:,'predicted_age_adj'] = X_test['predicted_age'].apply(lambda x: np.expm1(x))

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score, KFold
from sklearn.metrics import mean_squared_log_error, r2_score, mean_squared_error

print('Mean squared error: %.2f'% mean_squared_error(X_test['actual_age'], X_test['predicted_age']))
print('Root Mean squared error: %.2f'% np.sqrt(mean_squared_error(X_test['actual_age'], X_test['predicted_age'])))
print('Coefficient of determination: %.2f'% r2_score(X_test['actual_age'], X_test['predicted_age']))
# Out:
# Mean squared error: 16.88
# Root Mean squared error: 4.11
# Coefficient of determination: 0.05

# %%
df = df[df.Age < 30][{'Age', 'lang'}].value_counts().to_frame().reset_index().rename(columns = {0:'count'})

# %%
df.head(10)

# %%
df= df.pivot(index='Age', columns='lang', values='count').reset_index().fillna(0)

# %%
for cols in df.columns:
    df[cols] = df[cols].astype(int)

# %%
df.sort_values(by ='Age')
